# %% [markdown]
# <a href="https://colab.research.google.com/github/https-deeplearning-ai/tensorflow-1-public/blob/main/C4/W4/ungraded_labs/C4_W4_Lab_3_Sunspots_CNN_RNN_DNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Predicting Sunspots with Neural Networks
#
# At this point in the course, you should be able to explore different network architectures for forecasting. In the previous weeks, you've used DNNs, RNNs, and CNNs to build these different models. In the final practice lab for this course, you'll try one more configuration and that is a combination of all these types of networks: the data windows will pass through a convolution, followed by stacked LSTMs, followed by stacked dense layers. See if this improves results or you can just opt for simpler models.

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# ## Utilities

# %%
def plot_series(x, y, format="-", start=0, end=None,
                title=None, xlabel=None, ylabel=None, legend=None ):
    """
    Visualizes time series data

    Args:
      x (array of int) - contains values for the x-axis
      y (array of int or tuple of arrays) - contains the values for the y-axis
      format (string) - line style when plotting the graph
      start (int) - first time step to plot
      end (int) - last time step to plot
      title (string) - title of the plot
      xlabel (string) - label for the x-axis
      ylabel (string) - label for the y-axis
      legend (list of strings) - legend for the plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))

    # Check if there are more than two series to plot
    if type(y) is tuple:

      # Loop over the y elements
      for y_curr in y:

        # Plot the x and current y values
        plt.plot(x[start:end], y_curr[start:end], format)

    else:
      # Plot the x and y values
      plt.plot(x[start:end], y[start:end], format)

    # Label the x-axis
    plt.xlabel(xlabel)

    # Label the y-axis
    plt.ylabel(ylabel)

    # Set the legend
    if legend:
      plt.legend(legend)

    # Set the title
    plt.title(title)

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

# %% [markdown]
# ## Download and Preview the Dataset

# %%
# Download the Dataset
# !wget https://storage.googleapis.com/tensorflow-1-public/course4/Sunspots.csv
# Out:
# --2024-04-25 09:27:54--  https://storage.googleapis.com/tensorflow-1-public/course4/Sunspots.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 2404:6800:4003:c01::cf, 2404:6800:4003:c02::cf, 2404:6800:4003:c1a::cf, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|2404:6800:4003:c01::cf|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70827 (69K) [text/csv]
# Saving to: 'Sunspots.csv.2'
#
#      0K .......... .......... .......... .......... .......... 72%  257K 0s
#     50K .......... .........                                  100% 2,34M=0,2s
#
# 2024-04-25 09:27:55 (341 KB/s) - 'Sunspots.csv.2' saved [70827/70827]

# %%
# Initialize lists
time_step = []
sunspots = []

# Open CSV file
with open('./Sunspots.csv') as csvfile:

  # Initialize reader
  reader = csv.reader(csvfile, delimiter=',')

  # Skip the first line
  next(reader)

  # Append row and sunspot number to lists
  for row in reader:
    time_step.append(int(row[0]))
    sunspots.append(float(row[2]))

# Convert lists to numpy arrays
time = np.array(time_step)
series = np.array(sunspots)

# Preview the data
plot_series(time, series, xlabel='Month', ylabel='Monthly Mean Total Sunspot Number')

# %% [markdown]
# ## Split the Dataset

# %%
# Define the split time
split_time = 3000

# Get the train set
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

# %% [markdown]
# ## Prepare Features and Labels

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    dataset = dataset.shuffle(shuffle_buffer)

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)

    return dataset

# %% [markdown]
# As mentioned in the lectures, if your results don't look good, you can try tweaking the parameters here and see if the model will learn better.

# %%
# Parameters
window_size = 30
batch_size = 32
shuffle_buffer_size = 1000

# Generate the dataset windows
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# ## Build the Model
#
# You've seen these layers before and here is how it looks like when combined.

# %%
# Build the Model
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=64, kernel_size=3,
                      strides=1,
                      activation="relu",
                      padding='causal',
                      input_shape=[WINDOW_SIZE, 1]),
  tf.keras.layers.LSTM(64, return_sequences=True),
  tf.keras.layers.LSTM(64),
  tf.keras.layers.Dense(30, activation="relu"),
  tf.keras.layers.Dense(10, activation="relu"),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 400)
])
        tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1), input_shape=[None]),

 # Print the model summary
model.summary()
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# WARNING:tensorflow:From c:\Python312\Lib\site-packages\keras\src\backend\tensorflow\core.py:188: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 30, 64)         │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 30, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 30)             │         1,950 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           310 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            11 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 68,575 (267.87 KB)
#  Trainable params: 68,575 (267.87 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Tune the Learning Rate
#
# As usual, you will want to pick an optimal learning rate.

# %%
# Get initial weights
init_weights = model.get_weights()

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - loss: 143.7005 - learning_rate: 1.0000e-08
# Epoch 2/100
#  1/93 ━━━━━━━━━━━━━━━━━━━━ 16s 184ms/step - loss: 101.7330
# c:\Python312\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 91.1588 - learning_rate: 1.1220e-08
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 40.0311 - learning_rate: 1.2589e-08
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 36.3080 - learning_rate: 1.4125e-08
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 34.7623 - learning_rate: 1.5849e-08
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 32.7493 - learning_rate: 1.7783e-08
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 32.1657 - learning_rate: 1.9953e-08
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 30.4385 - learning_rate: 2.2387e-08
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 30.1234 - learning_rate: 2.5119e-08
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 28.5330 - learning_rate: 2.8184e-08
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 26.9314 - learning_rate: 3.1623e-08
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 26.8880 - learning_rate: 3.5481e-08
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 26.0079 - learning_rate: 3.9811e-08
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 26.1442 - learning_rate: 4.4668e-08
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 25.0649 - learning_rate: 5.0119e-08
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 23.8350 - learning_rate: 5.6234e-08
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 23.7955 - learning_rate: 6.3096e-08
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 24.2913 - learning_rate: 7.0795e-08
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 22.9774 - learning_rate: 7.9433e-08
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 22.6434 - learning_rate: 8.9125e-08
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.0124 - learning_rate: 1.0000e-07
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 21.8146 - learning_rate: 1.1220e-07
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 20.6198 - learning_rate: 1.2589e-07
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 21.2351 - learning_rate: 1.4125e-07
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 20.7297 - learning_rate: 1.5849e-07
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 20.0455 - learning_rate: 1.7783e-07
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 19.5292 - learning_rate: 1.9953e-07
# Epoch 28/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 19.7436 - learning_rate: 2.2387e-07
# Epoch 29/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 19.2957 - learning_rate: 2.5119e-07
# Epoch 30/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 18.9644 - learning_rate: 2.8184e-07
# Epoch 31/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 18.9719 - learning_rate: 3.1623e-07
# Epoch 32/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 18.3153 - learning_rate: 3.5481e-07
# Epoch 33/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 19.1969 - learning_rate: 3.9811e-07
# Epoch 34/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 18.1781 - learning_rate: 4.4668e-07
# Epoch 35/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 18.7154 - learning_rate: 5.0119e-07
# Epoch 36/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 17.9659 - learning_rate: 5.6234e-07
# Epoch 37/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 17.8381 - learning_rate: 6.3096e-07
# Epoch 38/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 17.9154 - learning_rate: 7.0795e-07
# Epoch 39/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 17.9606 - learning_rate: 7.9433e-07
# Epoch 40/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 19.5683 - learning_rate: 8.9125e-07
# Epoch 41/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 18.1696 - learning_rate: 1.0000e-06
# Epoch 42/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 17.9584 - learning_rate: 1.1220e-06
# Epoch 43/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 17.8310 - learning_rate: 1.2589e-06
# Epoch 44/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 18.2829 - learning_rate: 1.4125e-06
# Epoch 45/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 17.2725 - learning_rate: 1.5849e-06
# Epoch 46/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 18.3394 - learning_rate: 1.7783e-06
# Epoch 47/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 18.8259 - learning_rate: 1.9953e-06
# Epoch 48/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 18.2297 - learning_rate: 2.2387e-06
# Epoch 49/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 18.9252 - learning_rate: 2.5119e-06
# Epoch 50/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 17.8485 - learning_rate: 2.8184e-06
# Epoch 51/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 20.6947 - learning_rate: 3.1623e-06
# Epoch 52/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 18.0731 - learning_rate: 3.5481e-06
# Epoch 53/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 17.9754 - learning_rate: 3.9811e-06
# Epoch 54/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 19.1977 - learning_rate: 4.4668e-06
# Epoch 55/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 19.6156 - learning_rate: 5.0119e-06
# Epoch 56/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 18.2491 - learning_rate: 5.6234e-06
# Epoch 57/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 19.4075 - learning_rate: 6.3096e-06
# Epoch 58/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 20.6420 - learning_rate: 7.0795e-06
# Epoch 59/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 18.8883 - learning_rate: 7.9433e-06
# Epoch 60/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 18.6216 - learning_rate: 8.9125e-06
# Epoch 61/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 18.9441 - learning_rate: 1.0000e-05
# Epoch 62/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 18.6064 - learning_rate: 1.1220e-05
# Epoch 63/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 19.5902 - learning_rate: 1.2589e-05
# Epoch 64/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 20.1945 - learning_rate: 1.4125e-05
# Epoch 65/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 21.1339 - learning_rate: 1.5849e-05
# Epoch 66/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 19.7015 - learning_rate: 1.7783e-05
# Epoch 67/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 19.2812 - learning_rate: 1.9953e-05
# Epoch 68/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 23.0544 - learning_rate: 2.2387e-05
# Epoch 69/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 23.0560 - learning_rate: 2.5119e-05
# Epoch 70/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 19.4890 - learning_rate: 2.8184e-05
# Epoch 71/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.5289 - learning_rate: 3.1623e-05
# Epoch 72/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 19.8995 - learning_rate: 3.5481e-05
# Epoch 73/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 20.3546 - learning_rate: 3.9811e-05
# Epoch 74/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 21.3175 - learning_rate: 4.4668e-05
# Epoch 75/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 23.2195 - learning_rate: 5.0119e-05
# Epoch 76/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 19.3408 - learning_rate: 5.6234e-05
# Epoch 77/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 21.8479 - learning_rate: 6.3096e-05
# Epoch 78/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 22.2925 - learning_rate: 7.0795e-05
# Epoch 79/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 24.9109 - learning_rate: 7.9433e-05
# Epoch 80/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 24.1162 - learning_rate: 8.9125e-05
# Epoch 81/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 30.6015 - learning_rate: 1.0000e-04
# Epoch 82/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 24.3267 - learning_rate: 1.1220e-04
# Epoch 83/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 23.5538 - learning_rate: 1.2589e-04
# Epoch 84/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 28.0604 - learning_rate: 1.4125e-04
# Epoch 85/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 30.3223 - learning_rate: 1.5849e-04
# Epoch 86/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 26.8340 - learning_rate: 1.7783e-04
# Epoch 87/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 25.5962 - learning_rate: 1.9953e-04
# Epoch 88/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 30.8691 - learning_rate: 2.2387e-04
# Epoch 89/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 34.2041 - learning_rate: 2.5119e-04
# Epoch 90/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 49.3848 - learning_rate: 2.8184e-04
# Epoch 91/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 51.7672 - learning_rate: 3.1623e-04
# Epoch 92/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 54.9794 - learning_rate: 3.5481e-04
# Epoch 93/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 53.8736 - learning_rate: 3.9811e-04
# Epoch 94/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 54.9666 - learning_rate: 4.4668e-04
# Epoch 95/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 61.3089 - learning_rate: 5.0119e-04
# Epoch 96/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 53.3545 - learning_rate: 5.6234e-04
# Epoch 97/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 54.1585 - learning_rate: 6.3096e-04
# Epoch 98/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 61.7970 - learning_rate: 7.0795e-04
# Epoch 99/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 63.9218 - learning_rate: 7.9433e-04
# Epoch 100/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 72.2624 - learning_rate: 8.9125e-04

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(100) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the loss in log scale
plt.semilogx(lrs, history.history["loss"])

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-3, 0, 100])
# Out:
# (1e-08, 0.001, 0.0, 100.0)

# %% [markdown]
# ## Train the Model
#
# Now you can proceed to reset and train the model. It is set for 100 epochs in the cell below but feel free to increase it if you want. Laurence got his results in the lectures after 500.

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

# Reset the weights
model.set_weights(init_weights)

# %%
# Set the learning rate
learning_rate = 8e-7

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# %%
# Train the model
history = model.fit(train_set,epochs=100)
# Out:
# Epoch 1/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 63.6270 - mae: 64.1296
# Epoch 2/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 21.0212 - mae: 21.5157
# Epoch 3/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 20.0242 - mae: 20.5191
# Epoch 4/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 18.8221 - mae: 19.3174
# Epoch 5/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 18.9801 - mae: 19.4754
# Epoch 6/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 19.4366 - mae: 19.9316
# Epoch 7/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 17.9068 - mae: 18.4006
# Epoch 8/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 19.4779 - mae: 19.9722
# Epoch 9/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 18.9273 - mae: 19.4207
# Epoch 10/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 17.9103 - mae: 18.4053
# Epoch 11/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 19.0235 - mae: 19.5173
# Epoch 12/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 18.3274 - mae: 18.8215
# Epoch 13/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 17.9298 - mae: 18.4239
# Epoch 14/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 17.8529 - mae: 18.3456
# Epoch 15/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 18.0455 - mae: 18.5358
# Epoch 16/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 17.5859 - mae: 18.0793
# Epoch 17/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 17.5406 - mae: 18.0328
# Epoch 18/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 17.4621 - mae: 17.9550
# Epoch 19/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 17.3821 - mae: 17.8751
# Epoch 20/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 17.2704 - mae: 17.7635
# Epoch 21/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 18.0236 - mae: 18.5158
# Epoch 22/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 16.7797 - mae: 17.2727
# Epoch 23/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 17.2420 - mae: 17.7368
# Epoch 24/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 16.8576 - mae: 17.3495
# Epoch 25/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 16.8029 - mae: 17.2933
# Epoch 26/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 17.2153 - mae: 17.7040
# Epoch 27/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 17.0425 - mae: 17.5327
# Epoch 28/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 17.3978 - mae: 17.8908
# Epoch 29/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.7591 - mae: 17.2513
# Epoch 30/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 17.2442 - mae: 17.7366
# Epoch 31/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 17.7539 - mae: 18.2472
# Epoch 32/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 17.5527 - mae: 18.0455
# Epoch 33/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 17.0702 - mae: 17.5628
# Epoch 34/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 17.3734 - mae: 17.8672
# Epoch 35/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 17.6932 - mae: 18.1865
# Epoch 36/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 17.3440 - mae: 17.8371
# Epoch 37/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 17.3929 - mae: 17.8851
# Epoch 38/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 17.0607 - mae: 17.5499
# Epoch 39/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 17.0936 - mae: 17.5844
# Epoch 40/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 16.9951 - mae: 17.4886
# Epoch 41/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.9332 - mae: 17.4256
# Epoch 42/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 18.0529 - mae: 18.5459
# Epoch 43/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.4444 - mae: 16.9327
# Epoch 44/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 16.4389 - mae: 16.9268
# Epoch 45/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 17.6993 - mae: 18.1925
# Epoch 46/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.8975 - mae: 17.3904
# Epoch 47/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 17.3628 - mae: 17.8532
# Epoch 48/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 16.9858 - mae: 17.4777
# Epoch 49/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.5120 - mae: 17.0037
# Epoch 50/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.6219 - mae: 17.1107
# Epoch 51/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 17.3647 - mae: 17.8571
# Epoch 52/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 17.3060 - mae: 17.7983
# Epoch 53/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.5772 - mae: 17.0675
# Epoch 54/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.4983 - mae: 16.9878
# Epoch 55/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 17.6617 - mae: 18.1540
# Epoch 56/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 17.1868 - mae: 17.6779
# Epoch 57/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.6613 - mae: 17.1524
# Epoch 58/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.5414 - mae: 17.0296
# Epoch 59/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.2998 - mae: 16.7899
# Epoch 60/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 17.1480 - mae: 17.6410
# Epoch 61/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.7383 - mae: 17.2301
# Epoch 62/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 17.2811 - mae: 17.7753
# Epoch 63/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.8217 - mae: 17.3114
# Epoch 64/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.6313 - mae: 17.1214
# Epoch 65/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 16.7437 - mae: 17.2331
# Epoch 66/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.6739 - mae: 17.1649
# Epoch 67/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 17.4478 - mae: 17.9395
# Epoch 68/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.9289 - mae: 17.4226
# Epoch 69/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.9354 - mae: 17.4260
# Epoch 70/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 17.1718 - mae: 17.6650
# Epoch 71/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 17.1604 - mae: 17.6506
# Epoch 72/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.5027 - mae: 16.9898
# Epoch 73/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.8703 - mae: 17.3616
# Epoch 74/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.4227 - mae: 16.9117
# Epoch 75/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 16.7370 - mae: 17.2279
# Epoch 76/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.6094 - mae: 17.1012
# Epoch 77/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 17.1409 - mae: 17.6336
# Epoch 78/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 16.6143 - mae: 17.1051
# Epoch 79/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.6520 - mae: 17.1438
# Epoch 80/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 17.2230 - mae: 17.7136
# Epoch 81/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 17.2986 - mae: 17.7911
# Epoch 82/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.9797 - mae: 17.4703
# Epoch 83/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.7094 - mae: 17.1998
# Epoch 84/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 17.2979 - mae: 17.7939
# Epoch 85/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 17.2015 - mae: 17.6917
# Epoch 86/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.7870 - mae: 17.2778
# Epoch 87/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.8497 - mae: 17.3419
# Epoch 88/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.7177 - mae: 17.2110
# Epoch 89/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.3531 - mae: 16.8429
# Epoch 90/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 17.1836 - mae: 17.6743
# Epoch 91/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.6288 - mae: 17.1209
# Epoch 92/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.8145 - mae: 17.3070
# Epoch 93/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.4941 - mae: 16.9847
# Epoch 94/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.3782 - mae: 16.8687
# Epoch 95/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.6401 - mae: 17.1320
# Epoch 96/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.6347 - mae: 17.1251
# Epoch 97/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 16.2449 - mae: 16.7358
# Epoch 98/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 17.4196 - mae: 17.9138
# Epoch 99/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.5445 - mae: 17.0354
# Epoch 100/100
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 16.6681 - mae: 17.1577

# %% [markdown]
# You can visualize the training and see if the loss and MAE are still trending down.

# %%
# Get mae and loss from history log
mae=history.history['mae']
loss=history.history['loss']

# Get number of epochs
epochs=range(len(loss))

# Plot mae and loss
plot_series(
    x=epochs,
    y=(mae, loss),
    title='MAE and Loss',
    xlabel='MAE',
    ylabel='Loss',
    legend=['MAE', 'Loss']
    )

# Only plot the last 80% of the epochs
zoom_split = int(epochs[-1] * 0.2)
epochs_zoom = epochs[zoom_split:]
mae_zoom = mae[zoom_split:]
loss_zoom = loss[zoom_split:]

# Plot zoomed mae and loss
plot_series(
    x=epochs_zoom,
    y=(mae_zoom, loss_zoom),
    title='MAE and Loss',
    xlabel='MAE',
    ylabel='Loss',
    legend=['MAE', 'Loss']
    )

# %% [markdown]
# ## Model Prediction
#
# As before, you can get the predictions for the validation set time range and compute the metrics.

# %%
def model_forecast(model, series, window_size, batch_size):
    """Uses an input model to generate predictions on data windows

    Args:
      model (TF Keras Model) - model that accepts data windows
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the window
      batch_size (int) - the batch size

    Returns:
      forecast (numpy array) - array containing predictions
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda w: w.batch(window_size))

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)

    # Get predictions on the entire dataset
    forecast = model.predict(dataset)

    return forecast

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step

# %%
# Compute the MAE
print(tf.keras.metrics.mean_absolute_error(x_valid, results).numpy())
# Out:
# 14.17025

# %% [markdown]
# ## Wrap Up
#
# This concludes the final practice lab for this course! You implemented a deep and complex architecture composed of CNNs, RNNs, and DNNs. You'll be using the skills you developed throughout this course to complete the final assignment. Keep it up!

# %% [markdown]
# ## Optional
#
# In this optional section, you will look at another way to dynamically set the learning rate. As you may have noticed, training for a long time generates less and less changes to the loss and metrics. You can run the cell below to observe that again.

# %%
# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=1e-7, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Train the model
history = model.fit(train_set,epochs=10)
# Out:
# Epoch 1/10
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 15.9493 - mae: 16.4380
# Epoch 2/10
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 16.5891 - mae: 17.0799
# Epoch 3/10
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 16.1455 - mae: 16.6354
# Epoch 4/10
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 16.3817 - mae: 16.8714
# Epoch 5/10
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 15.8086 - mae: 16.2946
# Epoch 6/10
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.2828 - mae: 16.7734
# Epoch 7/10
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.2771 - mae: 16.7642
# Epoch 8/10
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 16.0890 - mae: 16.5798
# Epoch 9/10
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.0127 - mae: 16.5029
# Epoch 10/10
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.6164 - mae: 17.1041

# %% [markdown]
# At some point, the static learning rate you set might no longer be the optimal one when the model has been learning for some time. You may want to decrease it some more to see better improvements. One way to do that is to have your training loop gradually decay the learning rate per epoch. You can pass in a lambda function similar like the one you did for the learning rate scheduler earlier, or use [ExponentialDecay()](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/schedules/ExponentialDecay). This is a built in scheduler from the Keras API. This decays the learning rate defined by this function:
#
# ```
# def decayed_learning_rate(step):
#   return initial_learning_rate * decay_rate ^ (step / decay_steps)
# ```
#
# See how it is used below.

# %%
# Set the initial learning rate
initial_learning_rate=1e-7

# Define the scheduler
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=400,
    decay_rate=0.96,
    staircase=True)

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Train the model
history = model.fit(train_set,epochs=40)
# Out:
# Epoch 1/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 16.2073 - mae: 16.6956
# Epoch 2/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.2334 - mae: 16.7210
# Epoch 3/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.5601 - mae: 17.0485
# Epoch 4/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 16.3590 - mae: 16.8493
# Epoch 5/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.3761 - mae: 16.8650
# Epoch 6/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.0990 - mae: 16.5867
# Epoch 7/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.3733 - mae: 16.8618
# Epoch 8/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.2123 - mae: 16.6999
# Epoch 9/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.5820 - mae: 17.0714
# Epoch 10/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.2201 - mae: 16.7071
# Epoch 11/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.0366 - mae: 16.5254
# Epoch 12/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 16.6867 - mae: 17.1774
# Epoch 13/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.6287 - mae: 17.1166
# Epoch 14/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.0596 - mae: 16.5475
# Epoch 15/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.0379 - mae: 16.5255
# Epoch 16/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 15.9755 - mae: 16.4636
# Epoch 17/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 15.8738 - mae: 16.3616
# Epoch 18/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.0617 - mae: 16.5489
# Epoch 19/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 15.9531 - mae: 16.4417
# Epoch 20/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.5958 - mae: 17.0848
# Epoch 21/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.1229 - mae: 16.6088
# Epoch 22/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.0752 - mae: 16.5633
# Epoch 23/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.3802 - mae: 16.8665
# Epoch 24/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.1028 - mae: 16.5915
# Epoch 25/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.1765 - mae: 16.6661
# Epoch 26/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.1172 - mae: 16.6045
# Epoch 27/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.2622 - mae: 16.7504
# Epoch 28/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.5717 - mae: 17.0605
# Epoch 29/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.1609 - mae: 16.6474
# Epoch 30/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 15.8626 - mae: 16.3486
# Epoch 31/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.1166 - mae: 16.6060
# Epoch 32/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.1222 - mae: 16.6116
# Epoch 33/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.2095 - mae: 16.6968
# Epoch 34/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 16.5616 - mae: 17.0517
# Epoch 35/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.2560 - mae: 16.7432
# Epoch 36/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 16.4859 - mae: 16.9754
# Epoch 37/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.4120 - mae: 16.9003
# Epoch 38/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 16.0904 - mae: 16.5803
# Epoch 39/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 16.2285 - mae: 16.7158
# Epoch 40/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 15.9302 - mae: 16.4181

# %% [markdown]
# Now see the results by geting predicitons and computing the metrics.

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step

# %%
# Compute the MAE
tf.keras.metrics.mean_absolute_error(x_valid, results).numpy()
# Out:
# 13.831318
