# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
# !pip install pandas matplotlib scikit-learn

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
#comment here

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = 'ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 8)]                  0         []
#
#  dense (Dense)               (None, 128)                  1152      ['input_1[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 64)                   8256      ['dense_1[0][0]']
#
#  y1_output (Dense)           (None, 1)                    129       ['dense_1[0][0]']
#
#  y2_output (Dense)           (None, 1)                    65        ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 26114 (102.01 KB)
# Trainable params: 26114 (102.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# 62/62 [==============================] - 2s 16ms/step - loss: 222.8023 - y1_output_loss: 110.4151 - y2_output_loss: 112.3872 - y1_output_root_mean_squared_error: 10.5079 - y2_output_root_mean_squared_error: 10.6013 - val_loss: 37.8665 - val_y1_output_loss: 16.5627 - val_y2_output_loss: 21.3038 - val_y1_output_root_mean_squared_error: 4.0697 - val_y2_output_root_mean_squared_error: 4.6156
# Epoch 2/500
# 62/62 [==============================] - 0s 3ms/step - loss: 33.7211 - y1_output_loss: 12.9097 - y2_output_loss: 20.8114 - y1_output_root_mean_squared_error: 3.5930 - y2_output_root_mean_squared_error: 4.5619 - val_loss: 32.6915 - val_y1_output_loss: 12.1678 - val_y2_output_loss: 20.5237 - val_y1_output_root_mean_squared_error: 3.4882 - val_y2_output_root_mean_squared_error: 4.5303
# Epoch 3/500
# 62/62 [==============================] - 0s 4ms/step - loss: 26.1409 - y1_output_loss: 10.2504 - y2_output_loss: 15.8905 - y1_output_root_mean_squared_error: 3.2016 - y2_output_root_mean_squared_error: 3.9863 - val_loss: 26.0738 - val_y1_output_loss: 10.3681 - val_y2_output_loss: 15.7057 - val_y1_output_root_mean_squared_error: 3.2200 - val_y2_output_root_mean_squared_error: 3.9630
# Epoch 4/500
# 62/62 [==============================] - 0s 4ms/step - loss: 24.7531 - y1_output_loss: 9.7211 - y2_output_loss: 15.0320 - y1_output_root_mean_squared_error: 3.1179 - y2_output_root_mean_squared_error: 3.8771 - val_loss: 24.7702 - val_y1_output_loss: 10.7672 - val_y2_output_loss: 14.0030 - val_y1_output_root_mean_squared_error: 3.2813 - val_y2_output_root_mean_squared_error: 3.7421
# Epoch 5/500
# 62/62 [==============================] - 0s 3ms/step - loss: 22.8315 - y1_output_loss: 9.1554 - y2_output_loss: 13.6761 - y1_output_root_mean_squared_error: 3.0258 - y2_output_root_mean_squared_error: 3.6981 - val_loss: 59.8709 - val_y1_output_loss: 16.5851 - val_y2_output_loss: 43.2858 - val_y1_output_root_mean_squared_error: 4.0725 - val_y2_output_root_mean_squared_error: 6.5792
# Epoch 6/500
# 62/62 [==============================] - 0s 3ms/step - loss: 24.0250 - y1_output_loss: 8.8508 - y2_output_loss: 15.1742 - y1_output_root_mean_squared_error: 2.9750 - y2_output_root_mean_squared_error: 3.8954 - val_loss: 20.8112 - val_y1_output_loss: 9.1893 - val_y2_output_loss: 11.6219 - val_y1_output_root_mean_squared_error: 3.0314 - val_y2_output_root_mean_squared_error: 3.4091
# Epoch 7/500
# 62/62 [==============================] - 0s 3ms/step - loss: 21.6104 - y1_output_loss: 8.6906 - y2_output_loss: 12.9198 - y1_output_root_mean_squared_error: 2.9480 - y2_output_root_mean_squared_error: 3.5944 - val_loss: 32.1390 - val_y1_output_loss: 10.5513 - val_y2_output_loss: 21.5877 - val_y1_output_root_mean_squared_error: 3.2483 - val_y2_output_root_mean_squared_error: 4.6463
# Epoch 8/500
# 62/62 [==============================] - 0s 4ms/step - loss: 24.8990 - y1_output_loss: 9.2484 - y2_output_loss: 15.6506 - y1_output_root_mean_squared_error: 3.0411 - y2_output_root_mean_squared_error: 3.9561 - val_loss: 22.3033 - val_y1_output_loss: 9.0146 - val_y2_output_loss: 13.2887 - val_y1_output_root_mean_squared_error: 3.0024 - val_y2_output_root_mean_squared_error: 3.6454
# Epoch 9/500
# 62/62 [==============================] - 0s 4ms/step - loss: 28.7065 - y1_output_loss: 9.7700 - y2_output_loss: 18.9365 - y1_output_root_mean_squared_error: 3.1257 - y2_output_root_mean_squared_error: 4.3516 - val_loss: 23.5590 - val_y1_output_loss: 9.6030 - val_y2_output_loss: 13.9559 - val_y1_output_root_mean_squared_error: 3.0989 - val_y2_output_root_mean_squared_error: 3.7358
# Epoch 10/500
# 62/62 [==============================] - 0s 5ms/step - loss: 23.0958 - y1_output_loss: 8.6427 - y2_output_loss: 14.4531 - y1_output_root_mean_squared_error: 2.9398 - y2_output_root_mean_squared_error: 3.8017 - val_loss: 19.3796 - val_y1_output_loss: 8.9920 - val_y2_output_loss: 10.3876 - val_y1_output_root_mean_squared_error: 2.9987 - val_y2_output_root_mean_squared_error: 3.2230
# Epoch 11/500
# 62/62 [==============================] - 0s 6ms/step - loss: 20.6057 - y1_output_loss: 7.8100 - y2_output_loss: 12.7957 - y1_output_root_mean_squared_error: 2.7946 - y2_output_root_mean_squared_error: 3.5771 - val_loss: 27.8661 - val_y1_output_loss: 9.7989 - val_y2_output_loss: 18.0672 - val_y1_output_root_mean_squared_error: 3.1303 - val_y2_output_root_mean_squared_error: 4.2506
# Epoch 12/500
# 62/62 [==============================] - 0s 5ms/step - loss: 19.1429 - y1_output_loss: 7.7406 - y2_output_loss: 11.4024 - y1_output_root_mean_squared_error: 2.7822 - y2_output_root_mean_squared_error: 3.3767 - val_loss: 24.4264 - val_y1_output_loss: 10.1734 - val_y2_output_loss: 14.2529 - val_y1_output_root_mean_squared_error: 3.1896 - val_y2_output_root_mean_squared_error: 3.7753
# Epoch 13/500
# 62/62 [==============================] - 0s 4ms/step - loss: 21.3183 - y1_output_loss: 8.2542 - y2_output_loss: 13.0641 - y1_output_root_mean_squared_error: 2.8730 - y2_output_root_mean_squared_error: 3.6144 - val_loss: 18.1862 - val_y1_output_loss: 8.1567 - val_y2_output_loss: 10.0295 - val_y1_output_root_mean_squared_error: 2.8560 - val_y2_output_root_mean_squared_error: 3.1669
# Epoch 14/500
# 62/62 [==============================] - 0s 4ms/step - loss: 21.2655 - y1_output_loss: 8.1325 - y2_output_loss: 13.1329 - y1_output_root_mean_squared_error: 2.8518 - y2_output_root_mean_squared_error: 3.6239 - val_loss: 17.7778 - val_y1_output_loss: 7.7544 - val_y2_output_loss: 10.0234 - val_y1_output_root_mean_squared_error: 2.7847 - val_y2_output_root_mean_squared_error: 3.1660
# Epoch 15/500
# 62/62 [==============================] - 0s 3ms/step - loss: 18.9361 - y1_output_loss: 7.6156 - y2_output_loss: 11.3204 - y1_output_root_mean_squared_error: 2.7596 - y2_output_root_mean_squared_error: 3.3646 - val_loss: 35.1388 - val_y1_output_loss: 11.4002 - val_y2_output_loss: 23.7386 - val_y1_output_root_mean_squared_error: 3.3764 - val_y2_output_root_mean_squared_error: 4.8722
# Epoch 16/500
# 62/62 [==============================] - 0s 4ms/step - loss: 19.9605 - y1_output_loss: 7.8184 - y2_output_loss: 12.1421 - y1_output_root_mean_squared_error: 2.7961 - y2_output_root_mean_squared_error: 3.4845 - val_loss: 18.0543 - val_y1_output_loss: 7.6585 - val_y2_output_loss: 10.3959 - val_y1_output_root_mean_squared_error: 2.7674 - val_y2_output_root_mean_squared_error: 3.2243
# Epoch 17/500
# 62/62 [==============================] - 0s 4ms/step - loss: 20.6874 - y1_output_loss: 7.8098 - y2_output_loss: 12.8776 - y1_output_root_mean_squared_error: 2.7946 - y2_output_root_mean_squared_error: 3.5885 - val_loss: 33.2789 - val_y1_output_loss: 10.4005 - val_y2_output_loss: 22.8784 - val_y1_output_root_mean_squared_error: 3.2250 - val_y2_output_root_mean_squared_error: 4.7831
# Epoch 18/500
# 62/62 [==============================] - 0s 4ms/step - loss: 18.5277 - y1_output_loss: 7.5102 - y2_output_loss: 11.0176 - y1_output_root_mean_squared_error: 2.7405 - y2_output_root_mean_squared_error: 3.3193 - val_loss: 19.2352 - val_y1_output_loss: 7.4273 - val_y2_output_loss: 11.8080 - val_y1_output_root_mean_squared_error: 2.7253 - val_y2_output_root_mean_squared_error: 3.4363
# Epoch 19/500
# 62/62 [==============================] - 0s 4ms/step - loss: 20.0336 - y1_output_loss: 7.2529 - y2_output_loss: 12.7807 - y1_output_root_mean_squared_error: 2.6931 - y2_output_root_mean_squared_error: 3.5750 - val_loss: 25.3926 - val_y1_output_loss: 9.1530 - val_y2_output_loss: 16.2396 - val_y1_output_root_mean_squared_error: 3.0254 - val_y2_output_root_mean_squared_error: 4.0298
# Epoch 20/500
# 62/62 [==============================] - 0s 5ms/step - loss: 17.6662 - y1_output_loss: 6.9724 - y2_output_loss: 10.6938 - y1_output_root_mean_squared_error: 2.6405 - y2_output_root_mean_squared_error: 3.2701 - val_loss: 16.8918 - val_y1_output_loss: 6.5928 - val_y2_output_loss: 10.2991 - val_y1_output_root_mean_squared_error: 2.5676 - val_y2_output_root_mean_squared_error: 3.2092
# Epoch 21/500
# 62/62 [==============================] - 0s 4ms/step - loss: 22.9204 - y1_output_loss: 7.8987 - y2_output_loss: 15.0217 - y1_output_root_mean_squared_error: 2.8105 - y2_output_root_mean_squared_error: 3.8758 - val_loss: 17.1102 - val_y1_output_loss: 7.5438 - val_y2_output_loss: 9.5664 - val_y1_output_root_mean_squared_error: 2.7466 - val_y2_output_root_mean_squared_error: 3.0930
# Epoch 22/500
# 62/62 [==============================] - 0s 4ms/step - loss: 17.3142 - y1_output_loss: 6.6180 - y2_output_loss: 10.6962 - y1_output_root_mean_squared_error: 2.5726 - y2_output_root_mean_squared_error: 3.2705 - val_loss: 16.9472 - val_y1_output_loss: 7.5089 - val_y2_output_loss: 9.4383 - val_y1_output_root_mean_squared_error: 2.7402 - val_y2_output_root_mean_squared_error: 3.0722
# Epoch 23/500
# 62/62 [==============================] - 0s 3ms/step - loss: 15.7832 - y1_output_loss: 6.2085 - y2_output_loss: 9.5747 - y1_output_root_mean_squared_error: 2.4917 - y2_output_root_mean_squared_error: 3.0943 - val_loss: 15.4803 - val_y1_output_loss: 6.0103 - val_y2_output_loss: 9.4700 - val_y1_output_root_mean_squared_error: 2.4516 - val_y2_output_root_mean_squared_error: 3.0773
# Epoch 24/500
# 62/62 [==============================] - 0s 5ms/step - loss: 19.9022 - y1_output_loss: 6.8792 - y2_output_loss: 13.0230 - y1_output_root_mean_squared_error: 2.6228 - y2_output_root_mean_squared_error: 3.6087 - val_loss: 13.6747 - val_y1_output_loss: 6.0170 - val_y2_output_loss: 7.6577 - val_y1_output_root_mean_squared_error: 2.4529 - val_y2_output_root_mean_squared_error: 2.7673
# Epoch 25/500
# 62/62 [==============================] - 0s 4ms/step - loss: 16.7928 - y1_output_loss: 6.2458 - y2_output_loss: 10.5470 - y1_output_root_mean_squared_error: 2.4992 - y2_output_root_mean_squared_error: 3.2476 - val_loss: 61.0587 - val_y1_output_loss: 18.3810 - val_y2_output_loss: 42.6778 - val_y1_output_root_mean_squared_error: 4.2873 - val_y2_output_root_mean_squared_error: 6.5328
# Epoch 26/500
# 62/62 [==============================] - 0s 4ms/step - loss: 17.9316 - y1_output_loss: 6.5563 - y2_output_loss: 11.3754 - y1_output_root_mean_squared_error: 2.5605 - y2_output_root_mean_squared_error: 3.3727 - val_loss: 14.9569 - val_y1_output_loss: 6.5664 - val_y2_output_loss: 8.3905 - val_y1_output_root_mean_squared_error: 2.5625 - val_y2_output_root_mean_squared_error: 2.8966
# Epoch 27/500
# 62/62 [==============================] - 0s 4ms/step - loss: 14.4713 - y1_output_loss: 5.7346 - y2_output_loss: 8.7367 - y1_output_root_mean_squared_error: 2.3947 - y2_output_root_mean_squared_error: 2.9558 - val_loss: 14.8868 - val_y1_output_loss: 5.6623 - val_y2_output_loss: 9.2245 - val_y1_output_root_mean_squared_error: 2.3796 - val_y2_output_root_mean_squared_error: 3.0372
# Epoch 28/500
# 62/62 [==============================] - 0s 4ms/step - loss: 16.8662 - y1_output_loss: 5.9389 - y2_output_loss: 10.9273 - y1_output_root_mean_squared_error: 2.4370 - y2_output_root_mean_squared_error: 3.3056 - val_loss: 11.4319 - val_y1_output_loss: 4.6120 - val_y2_output_loss: 6.8200 - val_y1_output_root_mean_squared_error: 2.1475 - val_y2_output_root_mean_squared_error: 2.6115
# Epoch 29/500
# 62/62 [==============================] - 0s 5ms/step - loss: 12.6830 - y1_output_loss: 4.9020 - y2_output_loss: 7.7809 - y1_output_root_mean_squared_error: 2.2141 - y2_output_root_mean_squared_error: 2.7894 - val_loss: 13.3244 - val_y1_output_loss: 5.3685 - val_y2_output_loss: 7.9558 - val_y1_output_root_mean_squared_error: 2.3170 - val_y2_output_root_mean_squared_error: 2.8206
# Epoch 30/500
# 62/62 [==============================] - 0s 3ms/step - loss: 12.9268 - y1_output_loss: 4.9266 - y2_output_loss: 8.0002 - y1_output_root_mean_squared_error: 2.2196 - y2_output_root_mean_squared_error: 2.8285 - val_loss: 23.1314 - val_y1_output_loss: 7.4845 - val_y2_output_loss: 15.6469 - val_y1_output_root_mean_squared_error: 2.7358 - val_y2_output_root_mean_squared_error: 3.9556
# Epoch 31/500
# 62/62 [==============================] - 0s 5ms/step - loss: 13.3608 - y1_output_loss: 5.0565 - y2_output_loss: 8.3043 - y1_output_root_mean_squared_error: 2.2487 - y2_output_root_mean_squared_error: 2.8817 - val_loss: 11.2174 - val_y1_output_loss: 4.2030 - val_y2_output_loss: 7.0145 - val_y1_output_root_mean_squared_error: 2.0501 - val_y2_output_root_mean_squared_error: 2.6485
# Epoch 32/500
# 62/62 [==============================] - 0s 4ms/step - loss: 13.9182 - y1_output_loss: 5.0853 - y2_output_loss: 8.8329 - y1_output_root_mean_squared_error: 2.2551 - y2_output_root_mean_squared_error: 2.9720 - val_loss: 11.5862 - val_y1_output_loss: 4.4785 - val_y2_output_loss: 7.1077 - val_y1_output_root_mean_squared_error: 2.1163 - val_y2_output_root_mean_squared_error: 2.6660
# Epoch 33/500
# 62/62 [==============================] - 0s 4ms/step - loss: 14.1340 - y1_output_loss: 5.2258 - y2_output_loss: 8.9083 - y1_output_root_mean_squared_error: 2.2860 - y2_output_root_mean_squared_error: 2.9847 - val_loss: 17.0047 - val_y1_output_loss: 4.7933 - val_y2_output_loss: 12.2114 - val_y1_output_root_mean_squared_error: 2.1894 - val_y2_output_root_mean_squared_error: 3.4945
# Epoch 34/500
# 62/62 [==============================] - 0s 4ms/step - loss: 11.5751 - y1_output_loss: 4.3338 - y2_output_loss: 7.2414 - y1_output_root_mean_squared_error: 2.0818 - y2_output_root_mean_squared_error: 2.6910 - val_loss: 12.1185 - val_y1_output_loss: 5.0099 - val_y2_output_loss: 7.1086 - val_y1_output_root_mean_squared_error: 2.2383 - val_y2_output_root_mean_squared_error: 2.6662
# Epoch 35/500
# 62/62 [==============================] - 0s 4ms/step - loss: 11.4375 - y1_output_loss: 4.3495 - y2_output_loss: 7.0880 - y1_output_root_mean_squared_error: 2.0855 - y2_output_root_mean_squared_error: 2.6623 - val_loss: 10.3835 - val_y1_output_loss: 3.7681 - val_y2_output_loss: 6.6154 - val_y1_output_root_mean_squared_error: 1.9412 - val_y2_output_root_mean_squared_error: 2.5720
# Epoch 36/500
# 62/62 [==============================] - 0s 4ms/step - loss: 10.4835 - y1_output_loss: 3.8650 - y2_output_loss: 6.6186 - y1_output_root_mean_squared_error: 1.9660 - y2_output_root_mean_squared_error: 2.5727 - val_loss: 9.2876 - val_y1_output_loss: 3.4892 - val_y2_output_loss: 5.7984 - val_y1_output_root_mean_squared_error: 1.8679 - val_y2_output_root_mean_squared_error: 2.4080
# Epoch 37/500
# 62/62 [==============================] - 0s 4ms/step - loss: 11.3301 - y1_output_loss: 3.9309 - y2_output_loss: 7.3993 - y1_output_root_mean_squared_error: 1.9826 - y2_output_root_mean_squared_error: 2.7202 - val_loss: 17.1773 - val_y1_output_loss: 4.8541 - val_y2_output_loss: 12.3232 - val_y1_output_root_mean_squared_error: 2.2032 - val_y2_output_root_mean_squared_error: 3.5104
# Epoch 38/500
# 62/62 [==============================] - 0s 3ms/step - loss: 11.4552 - y1_output_loss: 4.2893 - y2_output_loss: 7.1660 - y1_output_root_mean_squared_error: 2.0711 - y2_output_root_mean_squared_error: 2.6769 - val_loss: 9.1762 - val_y1_output_loss: 3.4085 - val_y2_output_loss: 5.7678 - val_y1_output_root_mean_squared_error: 1.8462 - val_y2_output_root_mean_squared_error: 2.4016
# Epoch 39/500
# 62/62 [==============================] - 0s 3ms/step - loss: 11.4173 - y1_output_loss: 3.8658 - y2_output_loss: 7.5515 - y1_output_root_mean_squared_error: 1.9662 - y2_output_root_mean_squared_error: 2.7480 - val_loss: 8.0643 - val_y1_output_loss: 2.9904 - val_y2_output_loss: 5.0739 - val_y1_output_root_mean_squared_error: 1.7293 - val_y2_output_root_mean_squared_error: 2.2525
# Epoch 40/500
# 62/62 [==============================] - 0s 4ms/step - loss: 13.7474 - y1_output_loss: 4.3631 - y2_output_loss: 9.3842 - y1_output_root_mean_squared_error: 2.0888 - y2_output_root_mean_squared_error: 3.0634 - val_loss: 8.1266 - val_y1_output_loss: 3.1173 - val_y2_output_loss: 5.0092 - val_y1_output_root_mean_squared_error: 1.7656 - val_y2_output_root_mean_squared_error: 2.2381
# Epoch 41/500
# 62/62 [==============================] - 0s 4ms/step - loss: 9.4235 - y1_output_loss: 3.5136 - y2_output_loss: 5.9098 - y1_output_root_mean_squared_error: 1.8745 - y2_output_root_mean_squared_error: 2.4310 - val_loss: 13.1017 - val_y1_output_loss: 5.4022 - val_y2_output_loss: 7.6995 - val_y1_output_root_mean_squared_error: 2.3243 - val_y2_output_root_mean_squared_error: 2.7748
# Epoch 42/500
# 62/62 [==============================] - 0s 5ms/step - loss: 9.2405 - y1_output_loss: 3.4069 - y2_output_loss: 5.8335 - y1_output_root_mean_squared_error: 1.8458 - y2_output_root_mean_squared_error: 2.4153 - val_loss: 7.8069 - val_y1_output_loss: 2.7020 - val_y2_output_loss: 5.1049 - val_y1_output_root_mean_squared_error: 1.6438 - val_y2_output_root_mean_squared_error: 2.2594
# Epoch 43/500
# 62/62 [==============================] - 0s 4ms/step - loss: 8.5659 - y1_output_loss: 3.0254 - y2_output_loss: 5.5405 - y1_output_root_mean_squared_error: 1.7394 - y2_output_root_mean_squared_error: 2.3538 - val_loss: 7.1470 - val_y1_output_loss: 2.4849 - val_y2_output_loss: 4.6621 - val_y1_output_root_mean_squared_error: 1.5764 - val_y2_output_root_mean_squared_error: 2.1592
# Epoch 44/500
# 62/62 [==============================] - 0s 5ms/step - loss: 9.0404 - y1_output_loss: 3.0564 - y2_output_loss: 5.9840 - y1_output_root_mean_squared_error: 1.7483 - y2_output_root_mean_squared_error: 2.4462 - val_loss: 13.2648 - val_y1_output_loss: 4.0157 - val_y2_output_loss: 9.2491 - val_y1_output_root_mean_squared_error: 2.0039 - val_y2_output_root_mean_squared_error: 3.0412
# Epoch 45/500
# 62/62 [==============================] - 0s 4ms/step - loss: 12.3071 - y1_output_loss: 4.0093 - y2_output_loss: 8.2978 - y1_output_root_mean_squared_error: 2.0023 - y2_output_root_mean_squared_error: 2.8806 - val_loss: 10.6616 - val_y1_output_loss: 4.0424 - val_y2_output_loss: 6.6192 - val_y1_output_root_mean_squared_error: 2.0106 - val_y2_output_root_mean_squared_error: 2.5728
# Epoch 46/500
# 62/62 [==============================] - 0s 4ms/step - loss: 8.4709 - y1_output_loss: 2.9990 - y2_output_loss: 5.4719 - y1_output_root_mean_squared_error: 1.7318 - y2_output_root_mean_squared_error: 2.3392 - val_loss: 7.7554 - val_y1_output_loss: 2.5844 - val_y2_output_loss: 5.1710 - val_y1_output_root_mean_squared_error: 1.6076 - val_y2_output_root_mean_squared_error: 2.2740
# Epoch 47/500
# 62/62 [==============================] - 0s 4ms/step - loss: 8.2034 - y1_output_loss: 2.6940 - y2_output_loss: 5.5094 - y1_output_root_mean_squared_error: 1.6413 - y2_output_root_mean_squared_error: 2.3472 - val_loss: 36.2963 - val_y1_output_loss: 6.1707 - val_y2_output_loss: 30.1256 - val_y1_output_root_mean_squared_error: 2.4841 - val_y2_output_root_mean_squared_error: 5.4887
# Epoch 48/500
# 62/62 [==============================] - 0s 4ms/step - loss: 8.0076 - y1_output_loss: 2.6531 - y2_output_loss: 5.3545 - y1_output_root_mean_squared_error: 1.6288 - y2_output_root_mean_squared_error: 2.3140 - val_loss: 15.0292 - val_y1_output_loss: 3.2701 - val_y2_output_loss: 11.7591 - val_y1_output_root_mean_squared_error: 1.8084 - val_y2_output_root_mean_squared_error: 3.4292
# Epoch 49/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.5069 - y1_output_loss: 2.6044 - y2_output_loss: 4.9025 - y1_output_root_mean_squared_error: 1.6138 - y2_output_root_mean_squared_error: 2.2142 - val_loss: 7.8734 - val_y1_output_loss: 2.8791 - val_y2_output_loss: 4.9944 - val_y1_output_root_mean_squared_error: 1.6968 - val_y2_output_root_mean_squared_error: 2.2348
# Epoch 50/500
# 62/62 [==============================] - 0s 4ms/step - loss: 14.1683 - y1_output_loss: 4.3089 - y2_output_loss: 9.8594 - y1_output_root_mean_squared_error: 2.0758 - y2_output_root_mean_squared_error: 3.1400 - val_loss: 25.3288 - val_y1_output_loss: 5.6773 - val_y2_output_loss: 19.6515 - val_y1_output_root_mean_squared_error: 2.3827 - val_y2_output_root_mean_squared_error: 4.4330
# Epoch 51/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.9448 - y1_output_loss: 2.6533 - y2_output_loss: 5.2915 - y1_output_root_mean_squared_error: 1.6289 - y2_output_root_mean_squared_error: 2.3003 - val_loss: 7.2021 - val_y1_output_loss: 2.2131 - val_y2_output_loss: 4.9889 - val_y1_output_root_mean_squared_error: 1.4877 - val_y2_output_root_mean_squared_error: 2.2336
# Epoch 52/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.8682 - y1_output_loss: 2.7518 - y2_output_loss: 5.1163 - y1_output_root_mean_squared_error: 1.6589 - y2_output_root_mean_squared_error: 2.2619 - val_loss: 14.0155 - val_y1_output_loss: 6.0888 - val_y2_output_loss: 7.9266 - val_y1_output_root_mean_squared_error: 2.4676 - val_y2_output_root_mean_squared_error: 2.8154
# Epoch 53/500
# 62/62 [==============================] - 0s 5ms/step - loss: 6.5055 - y1_output_loss: 2.2059 - y2_output_loss: 4.2996 - y1_output_root_mean_squared_error: 1.4852 - y2_output_root_mean_squared_error: 2.0735 - val_loss: 10.6990 - val_y1_output_loss: 3.3272 - val_y2_output_loss: 7.3718 - val_y1_output_root_mean_squared_error: 1.8241 - val_y2_output_root_mean_squared_error: 2.7151
# Epoch 54/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.1497 - y1_output_loss: 2.2293 - y2_output_loss: 4.9204 - y1_output_root_mean_squared_error: 1.4931 - y2_output_root_mean_squared_error: 2.2182 - val_loss: 6.3451 - val_y1_output_loss: 2.0485 - val_y2_output_loss: 4.2966 - val_y1_output_root_mean_squared_error: 1.4313 - val_y2_output_root_mean_squared_error: 2.0728
# Epoch 55/500
# 62/62 [==============================] - 0s 5ms/step - loss: 6.1499 - y1_output_loss: 2.0759 - y2_output_loss: 4.0739 - y1_output_root_mean_squared_error: 1.4408 - y2_output_root_mean_squared_error: 2.0184 - val_loss: 9.6734 - val_y1_output_loss: 2.5702 - val_y2_output_loss: 7.1031 - val_y1_output_root_mean_squared_error: 1.6032 - val_y2_output_root_mean_squared_error: 2.6652
# Epoch 56/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.7185 - y1_output_loss: 2.3378 - y2_output_loss: 5.3807 - y1_output_root_mean_squared_error: 1.5290 - y2_output_root_mean_squared_error: 2.3196 - val_loss: 25.7162 - val_y1_output_loss: 9.8426 - val_y2_output_loss: 15.8736 - val_y1_output_root_mean_squared_error: 3.1373 - val_y2_output_root_mean_squared_error: 3.9842
# Epoch 57/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.8587 - y1_output_loss: 2.3757 - y2_output_loss: 4.4830 - y1_output_root_mean_squared_error: 1.5413 - y2_output_root_mean_squared_error: 2.1173 - val_loss: 6.5274 - val_y1_output_loss: 2.5390 - val_y2_output_loss: 3.9884 - val_y1_output_root_mean_squared_error: 1.5934 - val_y2_output_root_mean_squared_error: 1.9971
# Epoch 58/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.5320 - y1_output_loss: 2.2136 - y2_output_loss: 4.3183 - y1_output_root_mean_squared_error: 1.4878 - y2_output_root_mean_squared_error: 2.0781 - val_loss: 14.5588 - val_y1_output_loss: 3.0764 - val_y2_output_loss: 11.4825 - val_y1_output_root_mean_squared_error: 1.7540 - val_y2_output_root_mean_squared_error: 3.3886
# Epoch 59/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.6450 - y1_output_loss: 2.1405 - y2_output_loss: 4.5045 - y1_output_root_mean_squared_error: 1.4631 - y2_output_root_mean_squared_error: 2.1224 - val_loss: 7.2995 - val_y1_output_loss: 2.3122 - val_y2_output_loss: 4.9873 - val_y1_output_root_mean_squared_error: 1.5206 - val_y2_output_root_mean_squared_error: 2.2332
# Epoch 60/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.0307 - y1_output_loss: 2.4197 - y2_output_loss: 4.6109 - y1_output_root_mean_squared_error: 1.5555 - y2_output_root_mean_squared_error: 2.1473 - val_loss: 9.8159 - val_y1_output_loss: 2.5096 - val_y2_output_loss: 7.3063 - val_y1_output_root_mean_squared_error: 1.5842 - val_y2_output_root_mean_squared_error: 2.7030
# Epoch 61/500
# 62/62 [==============================] - 0s 5ms/step - loss: 9.1457 - y1_output_loss: 2.8844 - y2_output_loss: 6.2613 - y1_output_root_mean_squared_error: 1.6984 - y2_output_root_mean_squared_error: 2.5023 - val_loss: 7.8527 - val_y1_output_loss: 2.5899 - val_y2_output_loss: 5.2628 - val_y1_output_root_mean_squared_error: 1.6093 - val_y2_output_root_mean_squared_error: 2.2941
# Epoch 62/500
# 62/62 [==============================] - 0s 7ms/step - loss: 6.7260 - y1_output_loss: 2.2324 - y2_output_loss: 4.4936 - y1_output_root_mean_squared_error: 1.4941 - y2_output_root_mean_squared_error: 2.1198 - val_loss: 25.0299 - val_y1_output_loss: 7.2068 - val_y2_output_loss: 17.8231 - val_y1_output_root_mean_squared_error: 2.6846 - val_y2_output_root_mean_squared_error: 4.2217
# Epoch 63/500
# 62/62 [==============================] - 0s 6ms/step - loss: 6.1144 - y1_output_loss: 2.0605 - y2_output_loss: 4.0538 - y1_output_root_mean_squared_error: 1.4354 - y2_output_root_mean_squared_error: 2.0134 - val_loss: 6.3092 - val_y1_output_loss: 1.9422 - val_y2_output_loss: 4.3670 - val_y1_output_root_mean_squared_error: 1.3936 - val_y2_output_root_mean_squared_error: 2.0897
# Epoch 64/500
# 62/62 [==============================] - 0s 5ms/step - loss: 6.1908 - y1_output_loss: 1.9034 - y2_output_loss: 4.2875 - y1_output_root_mean_squared_error: 1.3796 - y2_output_root_mean_squared_error: 2.0706 - val_loss: 7.6811 - val_y1_output_loss: 1.9870 - val_y2_output_loss: 5.6942 - val_y1_output_root_mean_squared_error: 1.4096 - val_y2_output_root_mean_squared_error: 2.3862
# Epoch 65/500
# 62/62 [==============================] - 0s 4ms/step - loss: 14.1440 - y1_output_loss: 4.2605 - y2_output_loss: 9.8834 - y1_output_root_mean_squared_error: 2.0641 - y2_output_root_mean_squared_error: 3.1438 - val_loss: 5.5003 - val_y1_output_loss: 1.7478 - val_y2_output_loss: 3.7524 - val_y1_output_root_mean_squared_error: 1.3221 - val_y2_output_root_mean_squared_error: 1.9371
# Epoch 66/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.1687 - y1_output_loss: 2.0326 - y2_output_loss: 4.1361 - y1_output_root_mean_squared_error: 1.4257 - y2_output_root_mean_squared_error: 2.0337 - val_loss: 7.9712 - val_y1_output_loss: 2.3774 - val_y2_output_loss: 5.5938 - val_y1_output_root_mean_squared_error: 1.5419 - val_y2_output_root_mean_squared_error: 2.3651
# Epoch 67/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.9331 - y1_output_loss: 2.1910 - y2_output_loss: 4.7422 - y1_output_root_mean_squared_error: 1.4802 - y2_output_root_mean_squared_error: 2.1777 - val_loss: 10.4824 - val_y1_output_loss: 2.7086 - val_y2_output_loss: 7.7738 - val_y1_output_root_mean_squared_error: 1.6458 - val_y2_output_root_mean_squared_error: 2.7882
# Epoch 68/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.6650 - y1_output_loss: 2.0030 - y2_output_loss: 4.6620 - y1_output_root_mean_squared_error: 1.4153 - y2_output_root_mean_squared_error: 2.1592 - val_loss: 6.7080 - val_y1_output_loss: 1.4072 - val_y2_output_loss: 5.3008 - val_y1_output_root_mean_squared_error: 1.1863 - val_y2_output_root_mean_squared_error: 2.3023
# Epoch 69/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.6942 - y1_output_loss: 2.1470 - y2_output_loss: 4.5471 - y1_output_root_mean_squared_error: 1.4653 - y2_output_root_mean_squared_error: 2.1324 - val_loss: 5.0877 - val_y1_output_loss: 1.6054 - val_y2_output_loss: 3.4824 - val_y1_output_root_mean_squared_error: 1.2670 - val_y2_output_root_mean_squared_error: 1.8661
# Epoch 70/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5942 - y1_output_loss: 1.7039 - y2_output_loss: 3.8903 - y1_output_root_mean_squared_error: 1.3053 - y2_output_root_mean_squared_error: 1.9724 - val_loss: 5.2558 - val_y1_output_loss: 1.6645 - val_y2_output_loss: 3.5912 - val_y1_output_root_mean_squared_error: 1.2902 - val_y2_output_root_mean_squared_error: 1.8951
# Epoch 71/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.8593 - y1_output_loss: 1.4661 - y2_output_loss: 3.3932 - y1_output_root_mean_squared_error: 1.2108 - y2_output_root_mean_squared_error: 1.8421 - val_loss: 14.1410 - val_y1_output_loss: 2.6706 - val_y2_output_loss: 11.4703 - val_y1_output_root_mean_squared_error: 1.6342 - val_y2_output_root_mean_squared_error: 3.3868
# Epoch 72/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.7861 - y1_output_loss: 1.5320 - y2_output_loss: 3.2542 - y1_output_root_mean_squared_error: 1.2377 - y2_output_root_mean_squared_error: 1.8039 - val_loss: 4.7380 - val_y1_output_loss: 1.4626 - val_y2_output_loss: 3.2754 - val_y1_output_root_mean_squared_error: 1.2094 - val_y2_output_root_mean_squared_error: 1.8098
# Epoch 73/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.2036 - y1_output_loss: 1.5119 - y2_output_loss: 3.6917 - y1_output_root_mean_squared_error: 1.2296 - y2_output_root_mean_squared_error: 1.9214 - val_loss: 5.2491 - val_y1_output_loss: 1.7051 - val_y2_output_loss: 3.5440 - val_y1_output_root_mean_squared_error: 1.3058 - val_y2_output_root_mean_squared_error: 1.8825
# Epoch 74/500
# 62/62 [==============================] - 0s 5ms/step - loss: 5.1549 - y1_output_loss: 1.5116 - y2_output_loss: 3.6433 - y1_output_root_mean_squared_error: 1.2295 - y2_output_root_mean_squared_error: 1.9087 - val_loss: 27.3829 - val_y1_output_loss: 7.0453 - val_y2_output_loss: 20.3375 - val_y1_output_root_mean_squared_error: 2.6543 - val_y2_output_root_mean_squared_error: 4.5097
# Epoch 75/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.2210 - y1_output_loss: 1.5963 - y2_output_loss: 3.6247 - y1_output_root_mean_squared_error: 1.2635 - y2_output_root_mean_squared_error: 1.9039 - val_loss: 5.1003 - val_y1_output_loss: 1.3838 - val_y2_output_loss: 3.7165 - val_y1_output_root_mean_squared_error: 1.1763 - val_y2_output_root_mean_squared_error: 1.9278
# Epoch 76/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.0902 - y1_output_loss: 1.9016 - y2_output_loss: 5.1886 - y1_output_root_mean_squared_error: 1.3790 - y2_output_root_mean_squared_error: 2.2779 - val_loss: 6.6583 - val_y1_output_loss: 1.6662 - val_y2_output_loss: 4.9921 - val_y1_output_root_mean_squared_error: 1.2908 - val_y2_output_root_mean_squared_error: 2.2343
# Epoch 77/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.7624 - y1_output_loss: 1.7455 - y2_output_loss: 4.0169 - y1_output_root_mean_squared_error: 1.3212 - y2_output_root_mean_squared_error: 2.0042 - val_loss: 15.4902 - val_y1_output_loss: 4.8094 - val_y2_output_loss: 10.6808 - val_y1_output_root_mean_squared_error: 2.1930 - val_y2_output_root_mean_squared_error: 3.2682
# Epoch 78/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.0822 - y1_output_loss: 1.7055 - y2_output_loss: 4.3767 - y1_output_root_mean_squared_error: 1.3059 - y2_output_root_mean_squared_error: 2.0921 - val_loss: 6.2572 - val_y1_output_loss: 2.0073 - val_y2_output_loss: 4.2499 - val_y1_output_root_mean_squared_error: 1.4168 - val_y2_output_root_mean_squared_error: 2.0615
# Epoch 79/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.2404 - y1_output_loss: 1.2460 - y2_output_loss: 2.9944 - y1_output_root_mean_squared_error: 1.1163 - y2_output_root_mean_squared_error: 1.7304 - val_loss: 8.5153 - val_y1_output_loss: 1.5452 - val_y2_output_loss: 6.9701 - val_y1_output_root_mean_squared_error: 1.2431 - val_y2_output_root_mean_squared_error: 2.6401
# Epoch 80/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.4719 - y1_output_loss: 1.2332 - y2_output_loss: 3.2388 - y1_output_root_mean_squared_error: 1.1105 - y2_output_root_mean_squared_error: 1.7997 - val_loss: 4.1390 - val_y1_output_loss: 1.3019 - val_y2_output_loss: 2.8371 - val_y1_output_root_mean_squared_error: 1.1410 - val_y2_output_root_mean_squared_error: 1.6844
# Epoch 81/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.5979 - y1_output_loss: 1.0877 - y2_output_loss: 2.5102 - y1_output_root_mean_squared_error: 1.0429 - y2_output_root_mean_squared_error: 1.5844 - val_loss: 6.6526 - val_y1_output_loss: 1.8407 - val_y2_output_loss: 4.8119 - val_y1_output_root_mean_squared_error: 1.3567 - val_y2_output_root_mean_squared_error: 2.1936
# Epoch 82/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.0704 - y1_output_loss: 1.2165 - y2_output_loss: 2.8539 - y1_output_root_mean_squared_error: 1.1029 - y2_output_root_mean_squared_error: 1.6893 - val_loss: 3.9127 - val_y1_output_loss: 1.3909 - val_y2_output_loss: 2.5218 - val_y1_output_root_mean_squared_error: 1.1794 - val_y2_output_root_mean_squared_error: 1.5880
# Epoch 83/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.3502 - y1_output_loss: 1.0166 - y2_output_loss: 2.3336 - y1_output_root_mean_squared_error: 1.0082 - y2_output_root_mean_squared_error: 1.5276 - val_loss: 3.7584 - val_y1_output_loss: 1.0958 - val_y2_output_loss: 2.6626 - val_y1_output_root_mean_squared_error: 1.0468 - val_y2_output_root_mean_squared_error: 1.6318
# Epoch 84/500
# 62/62 [==============================] - 0s 5ms/step - loss: 3.6793 - y1_output_loss: 0.9586 - y2_output_loss: 2.7207 - y1_output_root_mean_squared_error: 0.9791 - y2_output_root_mean_squared_error: 1.6495 - val_loss: 3.5287 - val_y1_output_loss: 0.8919 - val_y2_output_loss: 2.6368 - val_y1_output_root_mean_squared_error: 0.9444 - val_y2_output_root_mean_squared_error: 1.6238
# Epoch 85/500
# 62/62 [==============================] - 0s 5ms/step - loss: 3.6132 - y1_output_loss: 1.0166 - y2_output_loss: 2.5966 - y1_output_root_mean_squared_error: 1.0083 - y2_output_root_mean_squared_error: 1.6114 - val_loss: 56.5153 - val_y1_output_loss: 15.9947 - val_y2_output_loss: 40.5206 - val_y1_output_root_mean_squared_error: 3.9993 - val_y2_output_root_mean_squared_error: 6.3656
# Epoch 86/500
# 62/62 [==============================] - 0s 5ms/step - loss: 5.7955 - y1_output_loss: 1.7556 - y2_output_loss: 4.0399 - y1_output_root_mean_squared_error: 1.3250 - y2_output_root_mean_squared_error: 2.0099 - val_loss: 6.2190 - val_y1_output_loss: 1.2735 - val_y2_output_loss: 4.9455 - val_y1_output_root_mean_squared_error: 1.1285 - val_y2_output_root_mean_squared_error: 2.2239
# Epoch 87/500
# 62/62 [==============================] - 1s 8ms/step - loss: 3.7954 - y1_output_loss: 1.0427 - y2_output_loss: 2.7526 - y1_output_root_mean_squared_error: 1.0211 - y2_output_root_mean_squared_error: 1.6591 - val_loss: 3.9864 - val_y1_output_loss: 1.4098 - val_y2_output_loss: 2.5767 - val_y1_output_root_mean_squared_error: 1.1873 - val_y2_output_root_mean_squared_error: 1.6052
# Epoch 88/500
# 62/62 [==============================] - 0s 5ms/step - loss: 3.3206 - y1_output_loss: 0.8724 - y2_output_loss: 2.4482 - y1_output_root_mean_squared_error: 0.9340 - y2_output_root_mean_squared_error: 1.5647 - val_loss: 3.7958 - val_y1_output_loss: 0.8154 - val_y2_output_loss: 2.9804 - val_y1_output_root_mean_squared_error: 0.9030 - val_y2_output_root_mean_squared_error: 1.7264
# Epoch 89/500
# 62/62 [==============================] - 0s 8ms/step - loss: 3.5162 - y1_output_loss: 0.9980 - y2_output_loss: 2.5182 - y1_output_root_mean_squared_error: 0.9990 - y2_output_root_mean_squared_error: 1.5869 - val_loss: 3.1633 - val_y1_output_loss: 0.9130 - val_y2_output_loss: 2.2504 - val_y1_output_root_mean_squared_error: 0.9555 - val_y2_output_root_mean_squared_error: 1.5001
# Epoch 90/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.9505 - y1_output_loss: 0.7762 - y2_output_loss: 2.1743 - y1_output_root_mean_squared_error: 0.8810 - y2_output_root_mean_squared_error: 1.4745 - val_loss: 3.7019 - val_y1_output_loss: 1.1869 - val_y2_output_loss: 2.5150 - val_y1_output_root_mean_squared_error: 1.0894 - val_y2_output_root_mean_squared_error: 1.5859
# Epoch 91/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.9625 - y1_output_loss: 1.1174 - y2_output_loss: 2.8450 - y1_output_root_mean_squared_error: 1.0571 - y2_output_root_mean_squared_error: 1.6867 - val_loss: 3.7271 - val_y1_output_loss: 0.9342 - val_y2_output_loss: 2.7929 - val_y1_output_root_mean_squared_error: 0.9665 - val_y2_output_root_mean_squared_error: 1.6712
# Epoch 92/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.7644 - y1_output_loss: 0.9946 - y2_output_loss: 2.7699 - y1_output_root_mean_squared_error: 0.9973 - y2_output_root_mean_squared_error: 1.6643 - val_loss: 2.7922 - val_y1_output_loss: 0.8722 - val_y2_output_loss: 1.9200 - val_y1_output_root_mean_squared_error: 0.9339 - val_y2_output_root_mean_squared_error: 1.3856
# Epoch 93/500
# 62/62 [==============================] - 0s 7ms/step - loss: 8.1982 - y1_output_loss: 2.5820 - y2_output_loss: 5.6161 - y1_output_root_mean_squared_error: 1.6069 - y2_output_root_mean_squared_error: 2.3698 - val_loss: 7.7345 - val_y1_output_loss: 2.3300 - val_y2_output_loss: 5.4045 - val_y1_output_root_mean_squared_error: 1.5264 - val_y2_output_root_mean_squared_error: 2.3248
# Epoch 94/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.1419 - y1_output_loss: 1.4750 - y2_output_loss: 3.6669 - y1_output_root_mean_squared_error: 1.2145 - y2_output_root_mean_squared_error: 1.9149 - val_loss: 3.0908 - val_y1_output_loss: 0.8033 - val_y2_output_loss: 2.2875 - val_y1_output_root_mean_squared_error: 0.8963 - val_y2_output_root_mean_squared_error: 1.5125
# Epoch 95/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.8290 - y1_output_loss: 0.7075 - y2_output_loss: 2.1215 - y1_output_root_mean_squared_error: 0.8411 - y2_output_root_mean_squared_error: 1.4565 - val_loss: 6.5962 - val_y1_output_loss: 1.7500 - val_y2_output_loss: 4.8462 - val_y1_output_root_mean_squared_error: 1.3229 - val_y2_output_root_mean_squared_error: 2.2014
# Epoch 96/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.2421 - y1_output_loss: 1.4490 - y2_output_loss: 3.7931 - y1_output_root_mean_squared_error: 1.2037 - y2_output_root_mean_squared_error: 1.9476 - val_loss: 10.9445 - val_y1_output_loss: 2.1452 - val_y2_output_loss: 8.7994 - val_y1_output_root_mean_squared_error: 1.4646 - val_y2_output_root_mean_squared_error: 2.9664
# Epoch 97/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.2484 - y1_output_loss: 0.8870 - y2_output_loss: 2.3614 - y1_output_root_mean_squared_error: 0.9418 - y2_output_root_mean_squared_error: 1.5367 - val_loss: 2.6955 - val_y1_output_loss: 0.7459 - val_y2_output_loss: 1.9496 - val_y1_output_root_mean_squared_error: 0.8637 - val_y2_output_root_mean_squared_error: 1.3963
# Epoch 98/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.5213 - y1_output_loss: 0.6554 - y2_output_loss: 1.8659 - y1_output_root_mean_squared_error: 0.8096 - y2_output_root_mean_squared_error: 1.3660 - val_loss: 2.7422 - val_y1_output_loss: 0.7222 - val_y2_output_loss: 2.0199 - val_y1_output_root_mean_squared_error: 0.8498 - val_y2_output_root_mean_squared_error: 1.4212
# Epoch 99/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.8562 - y1_output_loss: 0.9379 - y2_output_loss: 2.9183 - y1_output_root_mean_squared_error: 0.9685 - y2_output_root_mean_squared_error: 1.7083 - val_loss: 4.1599 - val_y1_output_loss: 1.3400 - val_y2_output_loss: 2.8199 - val_y1_output_root_mean_squared_error: 1.1576 - val_y2_output_root_mean_squared_error: 1.6792
# Epoch 100/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.6715 - y1_output_loss: 0.7140 - y2_output_loss: 1.9576 - y1_output_root_mean_squared_error: 0.8450 - y2_output_root_mean_squared_error: 1.3991 - val_loss: 61.8633 - val_y1_output_loss: 19.7943 - val_y2_output_loss: 42.0691 - val_y1_output_root_mean_squared_error: 4.4491 - val_y2_output_root_mean_squared_error: 6.4861
# Epoch 101/500
# 62/62 [==============================] - 0s 4ms/step - loss: 18.8574 - y1_output_loss: 5.8852 - y2_output_loss: 12.9722 - y1_output_root_mean_squared_error: 2.4259 - y2_output_root_mean_squared_error: 3.6017 - val_loss: 3.7200 - val_y1_output_loss: 0.9538 - val_y2_output_loss: 2.7662 - val_y1_output_root_mean_squared_error: 0.9766 - val_y2_output_root_mean_squared_error: 1.6632
# Epoch 102/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.3128 - y1_output_loss: 1.4214 - y2_output_loss: 3.8914 - y1_output_root_mean_squared_error: 1.1922 - y2_output_root_mean_squared_error: 1.9727 - val_loss: 3.3615 - val_y1_output_loss: 0.9725 - val_y2_output_loss: 2.3890 - val_y1_output_root_mean_squared_error: 0.9862 - val_y2_output_root_mean_squared_error: 1.5456
# Epoch 103/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.3171 - y1_output_loss: 0.6003 - y2_output_loss: 1.7168 - y1_output_root_mean_squared_error: 0.7748 - y2_output_root_mean_squared_error: 1.3103 - val_loss: 2.8307 - val_y1_output_loss: 0.8921 - val_y2_output_loss: 1.9386 - val_y1_output_root_mean_squared_error: 0.9445 - val_y2_output_root_mean_squared_error: 1.3924
# Epoch 104/500
# 62/62 [==============================] - 0s 6ms/step - loss: 2.4857 - y1_output_loss: 0.6195 - y2_output_loss: 1.8662 - y1_output_root_mean_squared_error: 0.7871 - y2_output_root_mean_squared_error: 1.3661 - val_loss: 2.6663 - val_y1_output_loss: 0.6675 - val_y2_output_loss: 1.9987 - val_y1_output_root_mean_squared_error: 0.8170 - val_y2_output_root_mean_squared_error: 1.4138
# Epoch 105/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.5920 - y1_output_loss: 0.5920 - y2_output_loss: 2.0000 - y1_output_root_mean_squared_error: 0.7694 - y2_output_root_mean_squared_error: 1.4142 - val_loss: 3.8844 - val_y1_output_loss: 1.2548 - val_y2_output_loss: 2.6296 - val_y1_output_root_mean_squared_error: 1.1202 - val_y2_output_root_mean_squared_error: 1.6216
# Epoch 106/500
# 62/62 [==============================] - 0s 5ms/step - loss: 3.5241 - y1_output_loss: 0.9086 - y2_output_loss: 2.6155 - y1_output_root_mean_squared_error: 0.9532 - y2_output_root_mean_squared_error: 1.6172 - val_loss: 3.1963 - val_y1_output_loss: 0.8486 - val_y2_output_loss: 2.3477 - val_y1_output_root_mean_squared_error: 0.9212 - val_y2_output_root_mean_squared_error: 1.5322
# Epoch 107/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.1201 - y1_output_loss: 0.7820 - y2_output_loss: 2.3380 - y1_output_root_mean_squared_error: 0.8843 - y2_output_root_mean_squared_error: 1.5291 - val_loss: 3.2627 - val_y1_output_loss: 0.8948 - val_y2_output_loss: 2.3679 - val_y1_output_root_mean_squared_error: 0.9459 - val_y2_output_root_mean_squared_error: 1.5388
# Epoch 108/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.9926 - y1_output_loss: 0.4771 - y2_output_loss: 1.5155 - y1_output_root_mean_squared_error: 0.6907 - y2_output_root_mean_squared_error: 1.2311 - val_loss: 4.3724 - val_y1_output_loss: 0.8199 - val_y2_output_loss: 3.5525 - val_y1_output_root_mean_squared_error: 0.9055 - val_y2_output_root_mean_squared_error: 1.8848
# Epoch 109/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.0999 - y1_output_loss: 0.7125 - y2_output_loss: 2.3874 - y1_output_root_mean_squared_error: 0.8441 - y2_output_root_mean_squared_error: 1.5451 - val_loss: 9.2970 - val_y1_output_loss: 1.1588 - val_y2_output_loss: 8.1383 - val_y1_output_root_mean_squared_error: 1.0765 - val_y2_output_root_mean_squared_error: 2.8528
# Epoch 110/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.5580 - y1_output_loss: 0.6704 - y2_output_loss: 1.8875 - y1_output_root_mean_squared_error: 0.8188 - y2_output_root_mean_squared_error: 1.3739 - val_loss: 8.7032 - val_y1_output_loss: 1.1639 - val_y2_output_loss: 7.5393 - val_y1_output_root_mean_squared_error: 1.0788 - val_y2_output_root_mean_squared_error: 2.7458
# Epoch 111/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.1392 - y1_output_loss: 0.8796 - y2_output_loss: 2.2596 - y1_output_root_mean_squared_error: 0.9378 - y2_output_root_mean_squared_error: 1.5032 - val_loss: 2.6849 - val_y1_output_loss: 0.7328 - val_y2_output_loss: 1.9521 - val_y1_output_root_mean_squared_error: 0.8561 - val_y2_output_root_mean_squared_error: 1.3972
# Epoch 112/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.5326 - y1_output_loss: 0.8825 - y2_output_loss: 2.6501 - y1_output_root_mean_squared_error: 0.9394 - y2_output_root_mean_squared_error: 1.6279 - val_loss: 2.9832 - val_y1_output_loss: 0.6197 - val_y2_output_loss: 2.3635 - val_y1_output_root_mean_squared_error: 0.7872 - val_y2_output_root_mean_squared_error: 1.5374
# Epoch 113/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.3518 - y1_output_loss: 0.5738 - y2_output_loss: 1.7781 - y1_output_root_mean_squared_error: 0.7575 - y2_output_root_mean_squared_error: 1.3334 - val_loss: 4.5075 - val_y1_output_loss: 0.9876 - val_y2_output_loss: 3.5199 - val_y1_output_root_mean_squared_error: 0.9938 - val_y2_output_root_mean_squared_error: 1.8761
# Epoch 114/500
# 62/62 [==============================] - 0s 7ms/step - loss: 2.6394 - y1_output_loss: 0.6075 - y2_output_loss: 2.0319 - y1_output_root_mean_squared_error: 0.7794 - y2_output_root_mean_squared_error: 1.4254 - val_loss: 8.8752 - val_y1_output_loss: 1.4848 - val_y2_output_loss: 7.3904 - val_y1_output_root_mean_squared_error: 1.2185 - val_y2_output_root_mean_squared_error: 2.7185
# Epoch 115/500
# 62/62 [==============================] - 0s 5ms/step - loss: 2.5117 - y1_output_loss: 0.6351 - y2_output_loss: 1.8766 - y1_output_root_mean_squared_error: 0.7970 - y2_output_root_mean_squared_error: 1.3699 - val_loss: 2.6754 - val_y1_output_loss: 0.8329 - val_y2_output_loss: 1.8425 - val_y1_output_root_mean_squared_error: 0.9126 - val_y2_output_root_mean_squared_error: 1.3574
# Epoch 116/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.1528 - y1_output_loss: 0.4915 - y2_output_loss: 1.6614 - y1_output_root_mean_squared_error: 0.7010 - y2_output_root_mean_squared_error: 1.2889 - val_loss: 2.3461 - val_y1_output_loss: 0.6440 - val_y2_output_loss: 1.7020 - val_y1_output_root_mean_squared_error: 0.8025 - val_y2_output_root_mean_squared_error: 1.3046
# Epoch 117/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.5645 - y1_output_loss: 0.6704 - y2_output_loss: 1.8940 - y1_output_root_mean_squared_error: 0.8188 - y2_output_root_mean_squared_error: 1.3762 - val_loss: 3.5180 - val_y1_output_loss: 0.8829 - val_y2_output_loss: 2.6351 - val_y1_output_root_mean_squared_error: 0.9396 - val_y2_output_root_mean_squared_error: 1.6233
# Epoch 118/500
# 62/62 [==============================] - 0s 7ms/step - loss: 2.0548 - y1_output_loss: 0.5296 - y2_output_loss: 1.5253 - y1_output_root_mean_squared_error: 0.7277 - y2_output_root_mean_squared_error: 1.2350 - val_loss: 3.0299 - val_y1_output_loss: 0.6711 - val_y2_output_loss: 2.3588 - val_y1_output_root_mean_squared_error: 0.8192 - val_y2_output_root_mean_squared_error: 1.5358
# Epoch 119/500
# 62/62 [==============================] - 0s 5ms/step - loss: 2.5196 - y1_output_loss: 0.5918 - y2_output_loss: 1.9278 - y1_output_root_mean_squared_error: 0.7693 - y2_output_root_mean_squared_error: 1.3885 - val_loss: 3.7576 - val_y1_output_loss: 0.6380 - val_y2_output_loss: 3.1196 - val_y1_output_root_mean_squared_error: 0.7987 - val_y2_output_root_mean_squared_error: 1.7662
# Epoch 120/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.4790 - y1_output_loss: 0.5961 - y2_output_loss: 1.8829 - y1_output_root_mean_squared_error: 0.7721 - y2_output_root_mean_squared_error: 1.3722 - val_loss: 2.5536 - val_y1_output_loss: 0.6616 - val_y2_output_loss: 1.8920 - val_y1_output_root_mean_squared_error: 0.8134 - val_y2_output_root_mean_squared_error: 1.3755
# Epoch 121/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.2165 - y1_output_loss: 0.5433 - y2_output_loss: 1.6732 - y1_output_root_mean_squared_error: 0.7371 - y2_output_root_mean_squared_error: 1.2935 - val_loss: 2.0684 - val_y1_output_loss: 0.5241 - val_y2_output_loss: 1.5443 - val_y1_output_root_mean_squared_error: 0.7240 - val_y2_output_root_mean_squared_error: 1.2427
# Epoch 122/500
# ...
# Epoch 461/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3867 - y1_output_loss: 0.1096 - y2_output_loss: 0.2771 - y1_output_root_mean_squared_error: 0.3311 - y2_output_root_mean_squared_error: 0.5264 - val_loss: 1.2051 - val_y1_output_loss: 0.2866 - val_y2_output_loss: 0.9184 - val_y1_output_root_mean_squared_error: 0.5354 - val_y2_output_root_mean_squared_error: 0.9583
# Epoch 462/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5115 - y1_output_loss: 0.1321 - y2_output_loss: 0.3794 - y1_output_root_mean_squared_error: 0.3634 - y2_output_root_mean_squared_error: 0.6159 - val_loss: 0.9697 - val_y1_output_loss: 0.2314 - val_y2_output_loss: 0.7383 - val_y1_output_root_mean_squared_error: 0.4811 - val_y2_output_root_mean_squared_error: 0.8592
# Epoch 463/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3905 - y1_output_loss: 0.1226 - y2_output_loss: 0.2679 - y1_output_root_mean_squared_error: 0.3501 - y2_output_root_mean_squared_error: 0.5176 - val_loss: 3.0538 - val_y1_output_loss: 0.3371 - val_y2_output_loss: 2.7167 - val_y1_output_root_mean_squared_error: 0.5806 - val_y2_output_root_mean_squared_error: 1.6482
# Epoch 464/500
# 62/62 [==============================] - 1s 10ms/step - loss: 0.4453 - y1_output_loss: 0.1265 - y2_output_loss: 0.3188 - y1_output_root_mean_squared_error: 0.3557 - y2_output_root_mean_squared_error: 0.5646 - val_loss: 1.0256 - val_y1_output_loss: 0.2203 - val_y2_output_loss: 0.8053 - val_y1_output_root_mean_squared_error: 0.4694 - val_y2_output_root_mean_squared_error: 0.8974
# Epoch 465/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4002 - y1_output_loss: 0.1311 - y2_output_loss: 0.2691 - y1_output_root_mean_squared_error: 0.3621 - y2_output_root_mean_squared_error: 0.5188 - val_loss: 1.5653 - val_y1_output_loss: 0.4367 - val_y2_output_loss: 1.1286 - val_y1_output_root_mean_squared_error: 0.6608 - val_y2_output_root_mean_squared_error: 1.0624
# Epoch 466/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6303 - y1_output_loss: 0.1965 - y2_output_loss: 0.4338 - y1_output_root_mean_squared_error: 0.4433 - y2_output_root_mean_squared_error: 0.6587 - val_loss: 1.0593 - val_y1_output_loss: 0.2145 - val_y2_output_loss: 0.8448 - val_y1_output_root_mean_squared_error: 0.4631 - val_y2_output_root_mean_squared_error: 0.9191
# Epoch 467/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.5507 - y1_output_loss: 0.3986 - y2_output_loss: 1.1521 - y1_output_root_mean_squared_error: 0.6313 - y2_output_root_mean_squared_error: 1.0734 - val_loss: 0.8893 - val_y1_output_loss: 0.1964 - val_y2_output_loss: 0.6928 - val_y1_output_root_mean_squared_error: 0.4432 - val_y2_output_root_mean_squared_error: 0.8324
# Epoch 468/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5856 - y1_output_loss: 0.1724 - y2_output_loss: 0.4132 - y1_output_root_mean_squared_error: 0.4152 - y2_output_root_mean_squared_error: 0.6428 - val_loss: 1.2542 - val_y1_output_loss: 0.2559 - val_y2_output_loss: 0.9984 - val_y1_output_root_mean_squared_error: 0.5058 - val_y2_output_root_mean_squared_error: 0.9992
# Epoch 469/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3712 - y1_output_loss: 0.1144 - y2_output_loss: 0.2568 - y1_output_root_mean_squared_error: 0.3382 - y2_output_root_mean_squared_error: 0.5068 - val_loss: 0.8306 - val_y1_output_loss: 0.1693 - val_y2_output_loss: 0.6613 - val_y1_output_root_mean_squared_error: 0.4114 - val_y2_output_root_mean_squared_error: 0.8132
# Epoch 470/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4396 - y1_output_loss: 0.1274 - y2_output_loss: 0.3122 - y1_output_root_mean_squared_error: 0.3569 - y2_output_root_mean_squared_error: 0.5587 - val_loss: 1.0365 - val_y1_output_loss: 0.2411 - val_y2_output_loss: 0.7954 - val_y1_output_root_mean_squared_error: 0.4910 - val_y2_output_root_mean_squared_error: 0.8918
# Epoch 471/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3953 - y1_output_loss: 0.1190 - y2_output_loss: 0.2763 - y1_output_root_mean_squared_error: 0.3450 - y2_output_root_mean_squared_error: 0.5256 - val_loss: 0.7626 - val_y1_output_loss: 0.1578 - val_y2_output_loss: 0.6048 - val_y1_output_root_mean_squared_error: 0.3972 - val_y2_output_root_mean_squared_error: 0.7777
# Epoch 472/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4934 - y1_output_loss: 0.1457 - y2_output_loss: 0.3478 - y1_output_root_mean_squared_error: 0.3817 - y2_output_root_mean_squared_error: 0.5897 - val_loss: 0.7707 - val_y1_output_loss: 0.1561 - val_y2_output_loss: 0.6147 - val_y1_output_root_mean_squared_error: 0.3951 - val_y2_output_root_mean_squared_error: 0.7840
# Epoch 473/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3857 - y1_output_loss: 0.1168 - y2_output_loss: 0.2689 - y1_output_root_mean_squared_error: 0.3417 - y2_output_root_mean_squared_error: 0.5186 - val_loss: 1.9637 - val_y1_output_loss: 0.3081 - val_y2_output_loss: 1.6556 - val_y1_output_root_mean_squared_error: 0.5551 - val_y2_output_root_mean_squared_error: 1.2867
# Epoch 474/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4860 - y1_output_loss: 0.1586 - y2_output_loss: 0.3274 - y1_output_root_mean_squared_error: 0.3982 - y2_output_root_mean_squared_error: 0.5722 - val_loss: 1.8443 - val_y1_output_loss: 0.3955 - val_y2_output_loss: 1.4489 - val_y1_output_root_mean_squared_error: 0.6289 - val_y2_output_root_mean_squared_error: 1.2037
# Epoch 475/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5243 - y1_output_loss: 0.1413 - y2_output_loss: 0.3831 - y1_output_root_mean_squared_error: 0.3759 - y2_output_root_mean_squared_error: 0.6189 - val_loss: 1.7589 - val_y1_output_loss: 0.4655 - val_y2_output_loss: 1.2934 - val_y1_output_root_mean_squared_error: 0.6823 - val_y2_output_root_mean_squared_error: 1.1373
# Epoch 476/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4919 - y1_output_loss: 0.1264 - y2_output_loss: 0.3655 - y1_output_root_mean_squared_error: 0.3556 - y2_output_root_mean_squared_error: 0.6045 - val_loss: 0.8320 - val_y1_output_loss: 0.1926 - val_y2_output_loss: 0.6394 - val_y1_output_root_mean_squared_error: 0.4389 - val_y2_output_root_mean_squared_error: 0.7996
# Epoch 477/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5579 - y1_output_loss: 0.1352 - y2_output_loss: 0.4228 - y1_output_root_mean_squared_error: 0.3677 - y2_output_root_mean_squared_error: 0.6502 - val_loss: 1.6376 - val_y1_output_loss: 0.1761 - val_y2_output_loss: 1.4615 - val_y1_output_root_mean_squared_error: 0.4197 - val_y2_output_root_mean_squared_error: 1.2089
# Epoch 478/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4711 - y1_output_loss: 0.1359 - y2_output_loss: 0.3353 - y1_output_root_mean_squared_error: 0.3686 - y2_output_root_mean_squared_error: 0.5790 - val_loss: 0.9347 - val_y1_output_loss: 0.2765 - val_y2_output_loss: 0.6582 - val_y1_output_root_mean_squared_error: 0.5258 - val_y2_output_root_mean_squared_error: 0.8113
# Epoch 479/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4461 - y1_output_loss: 0.1258 - y2_output_loss: 0.3203 - y1_output_root_mean_squared_error: 0.3547 - y2_output_root_mean_squared_error: 0.5659 - val_loss: 0.9916 - val_y1_output_loss: 0.1983 - val_y2_output_loss: 0.7933 - val_y1_output_root_mean_squared_error: 0.4453 - val_y2_output_root_mean_squared_error: 0.8907
# Epoch 480/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3703 - y1_output_loss: 0.1103 - y2_output_loss: 0.2601 - y1_output_root_mean_squared_error: 0.3321 - y2_output_root_mean_squared_error: 0.5100 - val_loss: 0.8355 - val_y1_output_loss: 0.1850 - val_y2_output_loss: 0.6505 - val_y1_output_root_mean_squared_error: 0.4301 - val_y2_output_root_mean_squared_error: 0.8065
# Epoch 481/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5233 - y1_output_loss: 0.1558 - y2_output_loss: 0.3675 - y1_output_root_mean_squared_error: 0.3947 - y2_output_root_mean_squared_error: 0.6062 - val_loss: 0.8610 - val_y1_output_loss: 0.1875 - val_y2_output_loss: 0.6735 - val_y1_output_root_mean_squared_error: 0.4330 - val_y2_output_root_mean_squared_error: 0.8207
# Epoch 482/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4765 - y1_output_loss: 0.1451 - y2_output_loss: 0.3314 - y1_output_root_mean_squared_error: 0.3810 - y2_output_root_mean_squared_error: 0.5757 - val_loss: 0.7817 - val_y1_output_loss: 0.1591 - val_y2_output_loss: 0.6225 - val_y1_output_root_mean_squared_error: 0.3989 - val_y2_output_root_mean_squared_error: 0.7890
# Epoch 483/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4570 - y1_output_loss: 0.1286 - y2_output_loss: 0.3284 - y1_output_root_mean_squared_error: 0.3586 - y2_output_root_mean_squared_error: 0.5731 - val_loss: 1.2913 - val_y1_output_loss: 0.3290 - val_y2_output_loss: 0.9623 - val_y1_output_root_mean_squared_error: 0.5736 - val_y2_output_root_mean_squared_error: 0.9810
# Epoch 484/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3561 - y1_output_loss: 0.1124 - y2_output_loss: 0.2436 - y1_output_root_mean_squared_error: 0.3353 - y2_output_root_mean_squared_error: 0.4936 - val_loss: 1.1258 - val_y1_output_loss: 0.2525 - val_y2_output_loss: 0.8733 - val_y1_output_root_mean_squared_error: 0.5025 - val_y2_output_root_mean_squared_error: 0.9345
# Epoch 485/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5025 - y1_output_loss: 0.1372 - y2_output_loss: 0.3653 - y1_output_root_mean_squared_error: 0.3704 - y2_output_root_mean_squared_error: 0.6044 - val_loss: 0.7458 - val_y1_output_loss: 0.1507 - val_y2_output_loss: 0.5951 - val_y1_output_root_mean_squared_error: 0.3882 - val_y2_output_root_mean_squared_error: 0.7714
# Epoch 486/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3902 - y1_output_loss: 0.1187 - y2_output_loss: 0.2715 - y1_output_root_mean_squared_error: 0.3446 - y2_output_root_mean_squared_error: 0.5211 - val_loss: 1.2592 - val_y1_output_loss: 0.2091 - val_y2_output_loss: 1.0501 - val_y1_output_root_mean_squared_error: 0.4573 - val_y2_output_root_mean_squared_error: 1.0247
# Epoch 487/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4685 - y1_output_loss: 0.1394 - y2_output_loss: 0.3291 - y1_output_root_mean_squared_error: 0.3734 - y2_output_root_mean_squared_error: 0.5736 - val_loss: 1.3277 - val_y1_output_loss: 0.3708 - val_y2_output_loss: 0.9569 - val_y1_output_root_mean_squared_error: 0.6089 - val_y2_output_root_mean_squared_error: 0.9782
# Epoch 488/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4164 - y1_output_loss: 0.1244 - y2_output_loss: 0.2919 - y1_output_root_mean_squared_error: 0.3528 - y2_output_root_mean_squared_error: 0.5403 - val_loss: 0.7488 - val_y1_output_loss: 0.1634 - val_y2_output_loss: 0.5855 - val_y1_output_root_mean_squared_error: 0.4042 - val_y2_output_root_mean_squared_error: 0.7651
# Epoch 489/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4545 - y1_output_loss: 0.1355 - y2_output_loss: 0.3190 - y1_output_root_mean_squared_error: 0.3681 - y2_output_root_mean_squared_error: 0.5648 - val_loss: 1.2477 - val_y1_output_loss: 0.3705 - val_y2_output_loss: 0.8773 - val_y1_output_root_mean_squared_error: 0.6087 - val_y2_output_root_mean_squared_error: 0.9366
# Epoch 490/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3779 - y1_output_loss: 0.1203 - y2_output_loss: 0.2576 - y1_output_root_mean_squared_error: 0.3468 - y2_output_root_mean_squared_error: 0.5076 - val_loss: 0.8004 - val_y1_output_loss: 0.1856 - val_y2_output_loss: 0.6148 - val_y1_output_root_mean_squared_error: 0.4308 - val_y2_output_root_mean_squared_error: 0.7841
# Epoch 491/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4686 - y1_output_loss: 0.1487 - y2_output_loss: 0.3199 - y1_output_root_mean_squared_error: 0.3856 - y2_output_root_mean_squared_error: 0.5656 - val_loss: 0.8364 - val_y1_output_loss: 0.1982 - val_y2_output_loss: 0.6382 - val_y1_output_root_mean_squared_error: 0.4452 - val_y2_output_root_mean_squared_error: 0.7989
# Epoch 492/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3333 - y1_output_loss: 0.1134 - y2_output_loss: 0.2199 - y1_output_root_mean_squared_error: 0.3367 - y2_output_root_mean_squared_error: 0.4690 - val_loss: 1.1550 - val_y1_output_loss: 0.2068 - val_y2_output_loss: 0.9482 - val_y1_output_root_mean_squared_error: 0.4547 - val_y2_output_root_mean_squared_error: 0.9738
# Epoch 493/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6407 - y1_output_loss: 0.1998 - y2_output_loss: 0.4409 - y1_output_root_mean_squared_error: 0.4470 - y2_output_root_mean_squared_error: 0.6640 - val_loss: 0.8546 - val_y1_output_loss: 0.1980 - val_y2_output_loss: 0.6566 - val_y1_output_root_mean_squared_error: 0.4450 - val_y2_output_root_mean_squared_error: 0.8103
# Epoch 494/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4110 - y1_output_loss: 0.1279 - y2_output_loss: 0.2830 - y1_output_root_mean_squared_error: 0.3577 - y2_output_root_mean_squared_error: 0.5320 - val_loss: 1.2136 - val_y1_output_loss: 0.1881 - val_y2_output_loss: 1.0255 - val_y1_output_root_mean_squared_error: 0.4337 - val_y2_output_root_mean_squared_error: 1.0127
# Epoch 495/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3190 - y1_output_loss: 0.1021 - y2_output_loss: 0.2169 - y1_output_root_mean_squared_error: 0.3195 - y2_output_root_mean_squared_error: 0.4657 - val_loss: 0.8226 - val_y1_output_loss: 0.1890 - val_y2_output_loss: 0.6336 - val_y1_output_root_mean_squared_error: 0.4347 - val_y2_output_root_mean_squared_error: 0.7960
# Epoch 496/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3433 - y1_output_loss: 0.1171 - y2_output_loss: 0.2261 - y1_output_root_mean_squared_error: 0.3423 - y2_output_root_mean_squared_error: 0.4756 - val_loss: 0.9185 - val_y1_output_loss: 0.2079 - val_y2_output_loss: 0.7106 - val_y1_output_root_mean_squared_error: 0.4560 - val_y2_output_root_mean_squared_error: 0.8429
# Epoch 497/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4701 - y1_output_loss: 0.1378 - y2_output_loss: 0.3323 - y1_output_root_mean_squared_error: 0.3712 - y2_output_root_mean_squared_error: 0.5764 - val_loss: 0.8957 - val_y1_output_loss: 0.1871 - val_y2_output_loss: 0.7086 - val_y1_output_root_mean_squared_error: 0.4325 - val_y2_output_root_mean_squared_error: 0.8418
# Epoch 498/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4189 - y1_output_loss: 0.1273 - y2_output_loss: 0.2915 - y1_output_root_mean_squared_error: 0.3568 - y2_output_root_mean_squared_error: 0.5400 - val_loss: 0.9262 - val_y1_output_loss: 0.1908 - val_y2_output_loss: 0.7354 - val_y1_output_root_mean_squared_error: 0.4368 - val_y2_output_root_mean_squared_error: 0.8575
# Epoch 499/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5532 - y1_output_loss: 0.1439 - y2_output_loss: 0.4093 - y1_output_root_mean_squared_error: 0.3793 - y2_output_root_mean_squared_error: 0.6398 - val_loss: 0.7800 - val_y1_output_loss: 0.1645 - val_y2_output_loss: 0.6155 - val_y1_output_root_mean_squared_error: 0.4056 - val_y2_output_root_mean_squared_error: 0.7845
# Epoch 500/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3836 - y1_output_loss: 0.1194 - y2_output_loss: 0.2642 - y1_output_root_mean_squared_error: 0.3456 - y2_output_root_mean_squared_error: 0.5140 - val_loss: 5.7639 - val_y1_output_loss: 0.6965 - val_y2_output_loss: 5.0674 - val_y1_output_root_mean_squared_error: 0.8346 - val_y2_output_root_mean_squared_error: 2.2511

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 5.7639 - y1_output_loss: 0.6965 - y2_output_loss: 5.0674 - y1_output_root_mean_squared_error: 0.8346 - y2_output_root_mean_squared_error: 2.2511
# Loss = 5.763915061950684, Y1_loss = 0.6965172290802002, Y1_mse = 0.8345760703086853, Y2_loss = 5.0673980712890625, Y2_mse = 2.2510881423950195

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
# Out:
# 5/5 [==============================] - 0s 2ms/step
