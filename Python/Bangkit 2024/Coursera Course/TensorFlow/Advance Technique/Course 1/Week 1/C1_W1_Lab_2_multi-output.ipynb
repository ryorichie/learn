# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
#comment here

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 5
#       2 URI = './data/ENB2012_data.xlsx'
#       4 # Use pandas excel reader
# ----> 5 df = pd.read_excel(URI)
#       6 df = df.sample(frac=1).reset_index(drop=True)
#       8 # Split the data into train and test with 80 train / 20 test
#
# File c:\Users\ryori\.conda\envs\python_tensorflow\lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File c:\Users\ryori\.conda\envs\python_tensorflow\lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File c:\Users\ryori\.conda\envs\python_tensorflow\lib\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File c:\Users\ryori\.conda\envs\python_tensorflow\lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/ENB2012_data.xlsx'

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 259.5750 - y1_output_loss: 121.8217 - y2_output_loss: 136.1591 - y1_output_root_mean_squared_error: 11.0689 - y2_output_root_mean_squared_error: 11.7070 - val_loss: 36.4488 - val_y1_output_loss: 12.3908 - val_y2_output_loss: 23.9117 - val_y1_output_root_mean_squared_error: 3.5766 - val_y2_output_root_mean_squared_error: 4.8638
# Epoch 2/500
# 614/614 [==============================] - 0s 181us/sample - loss: 36.4494 - y1_output_loss: 13.8010 - y2_output_loss: 22.3570 - y1_output_root_mean_squared_error: 3.7324 - y2_output_root_mean_squared_error: 4.7454 - val_loss: 38.5555 - val_y1_output_loss: 9.9928 - val_y2_output_loss: 28.8410 - val_y1_output_root_mean_squared_error: 3.0995 - val_y2_output_root_mean_squared_error: 5.3804
# Epoch 3/500
# 614/614 [==============================] - 0s 165us/sample - loss: 31.4579 - y1_output_loss: 11.3815 - y2_output_loss: 20.6601 - y1_output_root_mean_squared_error: 3.3416 - y2_output_root_mean_squared_error: 4.5046 - val_loss: 27.1110 - val_y1_output_loss: 12.3254 - val_y2_output_loss: 14.5381 - val_y1_output_root_mean_squared_error: 3.5099 - val_y2_output_root_mean_squared_error: 3.8460
# Epoch 4/500
# 614/614 [==============================] - 0s 165us/sample - loss: 30.3442 - y1_output_loss: 11.3236 - y2_output_loss: 19.2221 - y1_output_root_mean_squared_error: 3.3452 - y2_output_root_mean_squared_error: 4.3765 - val_loss: 30.2411 - val_y1_output_loss: 8.3936 - val_y2_output_loss: 22.6247 - val_y1_output_root_mean_squared_error: 2.8870 - val_y2_output_root_mean_squared_error: 4.6804
# Epoch 5/500
# 614/614 [==============================] - 0s 162us/sample - loss: 23.3380 - y1_output_loss: 9.4161 - y2_output_loss: 14.5143 - y1_output_root_mean_squared_error: 3.0089 - y2_output_root_mean_squared_error: 3.7795 - val_loss: 71.3270 - val_y1_output_loss: 24.6751 - val_y2_output_loss: 47.7987 - val_y1_output_root_mean_squared_error: 4.9433 - val_y2_output_root_mean_squared_error: 6.8477
# Epoch 6/500
# 614/614 [==============================] - 0s 153us/sample - loss: 26.1207 - y1_output_loss: 9.7709 - y2_output_loss: 16.2048 - y1_output_root_mean_squared_error: 3.1332 - y2_output_root_mean_squared_error: 4.0378 - val_loss: 68.8327 - val_y1_output_loss: 14.5747 - val_y2_output_loss: 54.1232 - val_y1_output_root_mean_squared_error: 3.7594 - val_y2_output_root_mean_squared_error: 7.3959
# Epoch 7/500
# 614/614 [==============================] - 0s 155us/sample - loss: 22.3238 - y1_output_loss: 9.1698 - y2_output_loss: 13.3340 - y1_output_root_mean_squared_error: 3.0040 - y2_output_root_mean_squared_error: 3.6469 - val_loss: 15.9752 - val_y1_output_loss: 7.5887 - val_y2_output_loss: 9.2752 - val_y1_output_root_mean_squared_error: 2.6608 - val_y2_output_root_mean_squared_error: 2.9825
# Epoch 8/500
# 614/614 [==============================] - 0s 171us/sample - loss: 21.5743 - y1_output_loss: 8.6638 - y2_output_loss: 12.8983 - y1_output_root_mean_squared_error: 2.9520 - y2_output_root_mean_squared_error: 3.5861 - val_loss: 66.0136 - val_y1_output_loss: 15.9306 - val_y2_output_loss: 50.7870 - val_y1_output_root_mean_squared_error: 3.8935 - val_y2_output_root_mean_squared_error: 7.1312
# Epoch 9/500
# 614/614 [==============================] - 0s 163us/sample - loss: 24.5035 - y1_output_loss: 9.3940 - y2_output_loss: 15.6582 - y1_output_root_mean_squared_error: 3.0123 - y2_output_root_mean_squared_error: 3.9280 - val_loss: 61.7227 - val_y1_output_loss: 13.4850 - val_y2_output_loss: 49.3111 - val_y1_output_root_mean_squared_error: 3.6560 - val_y2_output_root_mean_squared_error: 6.9539
# Epoch 10/500
# 614/614 [==============================] - 0s 168us/sample - loss: 21.3143 - y1_output_loss: 8.3366 - y2_output_loss: 13.1360 - y1_output_root_mean_squared_error: 2.8746 - y2_output_root_mean_squared_error: 3.6126 - val_loss: 16.3874 - val_y1_output_loss: 7.4397 - val_y2_output_loss: 9.5975 - val_y1_output_root_mean_squared_error: 2.6664 - val_y2_output_root_mean_squared_error: 3.0460
# Epoch 11/500
# 614/614 [==============================] - 0s 175us/sample - loss: 24.7226 - y1_output_loss: 8.5476 - y2_output_loss: 15.9812 - y1_output_root_mean_squared_error: 2.9356 - y2_output_root_mean_squared_error: 4.0131 - val_loss: 21.2276 - val_y1_output_loss: 8.6111 - val_y2_output_loss: 13.2011 - val_y1_output_root_mean_squared_error: 2.8606 - val_y2_output_root_mean_squared_error: 3.6117
# Epoch 12/500
# 614/614 [==============================] - 0s 170us/sample - loss: 21.6910 - y1_output_loss: 8.1815 - y2_output_loss: 13.4674 - y1_output_root_mean_squared_error: 2.8491 - y2_output_root_mean_squared_error: 3.6842 - val_loss: 22.6555 - val_y1_output_loss: 9.3455 - val_y2_output_loss: 13.6299 - val_y1_output_root_mean_squared_error: 2.9961 - val_y2_output_root_mean_squared_error: 3.6985
# Epoch 13/500
# 614/614 [==============================] - 0s 161us/sample - loss: 18.5665 - y1_output_loss: 7.2744 - y2_output_loss: 11.2121 - y1_output_root_mean_squared_error: 2.7004 - y2_output_root_mean_squared_error: 3.3578 - val_loss: 17.8078 - val_y1_output_loss: 8.1111 - val_y2_output_loss: 10.2211 - val_y1_output_root_mean_squared_error: 2.7741 - val_y2_output_root_mean_squared_error: 3.1800
# Epoch 14/500
# 614/614 [==============================] - 0s 154us/sample - loss: 19.3486 - y1_output_loss: 7.5037 - y2_output_loss: 11.9280 - y1_output_root_mean_squared_error: 2.7205 - y2_output_root_mean_squared_error: 3.4566 - val_loss: 13.8625 - val_y1_output_loss: 6.2507 - val_y2_output_loss: 8.0119 - val_y1_output_root_mean_squared_error: 2.4422 - val_y2_output_root_mean_squared_error: 2.8104
# Epoch 15/500
# 614/614 [==============================] - 0s 152us/sample - loss: 17.0403 - y1_output_loss: 6.8119 - y2_output_loss: 10.0847 - y1_output_root_mean_squared_error: 2.6209 - y2_output_root_mean_squared_error: 3.1892 - val_loss: 12.5976 - val_y1_output_loss: 5.7069 - val_y2_output_loss: 7.3602 - val_y1_output_root_mean_squared_error: 2.3240 - val_y2_output_root_mean_squared_error: 2.6827
# Epoch 16/500
# 614/614 [==============================] - 0s 154us/sample - loss: 18.1636 - y1_output_loss: 7.3959 - y2_output_loss: 10.8072 - y1_output_root_mean_squared_error: 2.7045 - y2_output_root_mean_squared_error: 3.2938 - val_loss: 15.4763 - val_y1_output_loss: 6.1367 - val_y2_output_loss: 10.0172 - val_y1_output_root_mean_squared_error: 2.4072 - val_y2_output_root_mean_squared_error: 3.1115
# Epoch 17/500
# 614/614 [==============================] - 0s 153us/sample - loss: 15.6632 - y1_output_loss: 6.1168 - y2_output_loss: 9.7656 - y1_output_root_mean_squared_error: 2.4721 - y2_output_root_mean_squared_error: 3.0906 - val_loss: 40.0653 - val_y1_output_loss: 8.8569 - val_y2_output_loss: 31.5252 - val_y1_output_root_mean_squared_error: 2.8919 - val_y2_output_root_mean_squared_error: 5.6305
# Epoch 18/500
# 614/614 [==============================] - 0s 155us/sample - loss: 14.9520 - y1_output_loss: 5.5044 - y2_output_loss: 9.3081 - y1_output_root_mean_squared_error: 2.3571 - y2_output_root_mean_squared_error: 3.0653 - val_loss: 11.9634 - val_y1_output_loss: 5.7200 - val_y2_output_loss: 6.9547 - val_y1_output_root_mean_squared_error: 2.2942 - val_y2_output_root_mean_squared_error: 2.5884
# Epoch 19/500
# 614/614 [==============================] - 0s 163us/sample - loss: 13.8538 - y1_output_loss: 5.5551 - y2_output_loss: 8.3461 - y1_output_root_mean_squared_error: 2.3650 - y2_output_root_mean_squared_error: 2.8741 - val_loss: 14.0390 - val_y1_output_loss: 5.5099 - val_y2_output_loss: 9.0387 - val_y1_output_root_mean_squared_error: 2.3025 - val_y2_output_root_mean_squared_error: 2.9559
# Epoch 20/500
# 614/614 [==============================] - 0s 153us/sample - loss: 13.8556 - y1_output_loss: 5.5596 - y2_output_loss: 8.4331 - y1_output_root_mean_squared_error: 2.3610 - y2_output_root_mean_squared_error: 2.8777 - val_loss: 38.2205 - val_y1_output_loss: 9.0182 - val_y2_output_loss: 29.4087 - val_y1_output_root_mean_squared_error: 2.9290 - val_y2_output_root_mean_squared_error: 5.4444
# Epoch 21/500
# 614/614 [==============================] - 0s 158us/sample - loss: 16.0649 - y1_output_loss: 5.9965 - y2_output_loss: 10.1963 - y1_output_root_mean_squared_error: 2.4242 - y2_output_root_mean_squared_error: 3.1919 - val_loss: 42.5050 - val_y1_output_loss: 13.8006 - val_y2_output_loss: 28.8989 - val_y1_output_root_mean_squared_error: 3.7331 - val_y2_output_root_mean_squared_error: 5.3450
# Epoch 22/500
# 614/614 [==============================] - 0s 160us/sample - loss: 13.4193 - y1_output_loss: 5.0078 - y2_output_loss: 8.4575 - y1_output_root_mean_squared_error: 2.2369 - y2_output_root_mean_squared_error: 2.9009 - val_loss: 21.9528 - val_y1_output_loss: 6.4323 - val_y2_output_loss: 15.7432 - val_y1_output_root_mean_squared_error: 2.5244 - val_y2_output_root_mean_squared_error: 3.9472
# Epoch 23/500
# 614/614 [==============================] - 0s 155us/sample - loss: 15.2899 - y1_output_loss: 5.5124 - y2_output_loss: 9.7108 - y1_output_root_mean_squared_error: 2.3462 - y2_output_root_mean_squared_error: 3.1282 - val_loss: 17.0489 - val_y1_output_loss: 5.3793 - val_y2_output_loss: 12.0697 - val_y1_output_root_mean_squared_error: 2.2697 - val_y2_output_root_mean_squared_error: 3.4493
# Epoch 24/500
# 614/614 [==============================] - 0s 153us/sample - loss: 13.1706 - y1_output_loss: 4.8405 - y2_output_loss: 8.3531 - y1_output_root_mean_squared_error: 2.1805 - y2_output_root_mean_squared_error: 2.9011 - val_loss: 12.9732 - val_y1_output_loss: 5.0043 - val_y2_output_loss: 8.6588 - val_y1_output_root_mean_squared_error: 2.1869 - val_y2_output_root_mean_squared_error: 2.8619
# Epoch 25/500
# 614/614 [==============================] - 0s 161us/sample - loss: 12.5291 - y1_output_loss: 4.5205 - y2_output_loss: 7.9186 - y1_output_root_mean_squared_error: 2.1357 - y2_output_root_mean_squared_error: 2.8227 - val_loss: 11.4925 - val_y1_output_loss: 4.7953 - val_y2_output_loss: 7.0100 - val_y1_output_root_mean_squared_error: 2.1225 - val_y2_output_root_mean_squared_error: 2.6434
# Epoch 26/500
# 614/614 [==============================] - 0s 156us/sample - loss: 11.2513 - y1_output_loss: 4.0548 - y2_output_loss: 7.0979 - y1_output_root_mean_squared_error: 2.0232 - y2_output_root_mean_squared_error: 2.6755 - val_loss: 9.4725 - val_y1_output_loss: 4.5049 - val_y2_output_loss: 5.3578 - val_y1_output_root_mean_squared_error: 2.0427 - val_y2_output_root_mean_squared_error: 2.3021
# Epoch 27/500
# 614/614 [==============================] - 0s 166us/sample - loss: 11.5038 - y1_output_loss: 4.3176 - y2_output_loss: 7.2956 - y1_output_root_mean_squared_error: 2.0574 - y2_output_root_mean_squared_error: 2.6964 - val_loss: 19.6426 - val_y1_output_loss: 4.7108 - val_y2_output_loss: 15.3571 - val_y1_output_root_mean_squared_error: 2.1203 - val_y2_output_root_mean_squared_error: 3.8919
# Epoch 28/500
# 614/614 [==============================] - 0s 156us/sample - loss: 12.0229 - y1_output_loss: 4.3736 - y2_output_loss: 7.5689 - y1_output_root_mean_squared_error: 2.0996 - y2_output_root_mean_squared_error: 2.7595 - val_loss: 10.8877 - val_y1_output_loss: 5.3832 - val_y2_output_loss: 5.9494 - val_y1_output_root_mean_squared_error: 2.2338 - val_y2_output_root_mean_squared_error: 2.4286
# Epoch 29/500
# 614/614 [==============================] - 0s 155us/sample - loss: 13.1885 - y1_output_loss: 4.4394 - y2_output_loss: 8.6823 - y1_output_root_mean_squared_error: 2.1135 - y2_output_root_mean_squared_error: 2.9532 - val_loss: 14.6572 - val_y1_output_loss: 4.5464 - val_y2_output_loss: 10.3543 - val_y1_output_root_mean_squared_error: 2.0568 - val_y2_output_root_mean_squared_error: 3.2291
# Epoch 30/500
# 614/614 [==============================] - 0s 163us/sample - loss: 10.0571 - y1_output_loss: 3.4109 - y2_output_loss: 6.5799 - y1_output_root_mean_squared_error: 1.8520 - y2_output_root_mean_squared_error: 2.5743 - val_loss: 7.5126 - val_y1_output_loss: 3.1036 - val_y2_output_loss: 4.6700 - val_y1_output_root_mean_squared_error: 1.7133 - val_y2_output_root_mean_squared_error: 2.1394
# Epoch 31/500
# 614/614 [==============================] - 0s 160us/sample - loss: 9.0827 - y1_output_loss: 3.3871 - y2_output_loss: 5.7242 - y1_output_root_mean_squared_error: 1.8324 - y2_output_root_mean_squared_error: 2.3927 - val_loss: 11.3811 - val_y1_output_loss: 3.8336 - val_y2_output_loss: 8.1590 - val_y1_output_root_mean_squared_error: 1.9016 - val_y2_output_root_mean_squared_error: 2.7866
# Epoch 32/500
# 614/614 [==============================] - 0s 165us/sample - loss: 9.7990 - y1_output_loss: 3.3002 - y2_output_loss: 6.4474 - y1_output_root_mean_squared_error: 1.8238 - y2_output_root_mean_squared_error: 2.5442 - val_loss: 8.7486 - val_y1_output_loss: 3.1272 - val_y2_output_loss: 6.1230 - val_y1_output_root_mean_squared_error: 1.6848 - val_y2_output_root_mean_squared_error: 2.4311
# Epoch 33/500
# 614/614 [==============================] - 0s 163us/sample - loss: 11.0853 - y1_output_loss: 4.0053 - y2_output_loss: 6.9861 - y1_output_root_mean_squared_error: 2.0105 - y2_output_root_mean_squared_error: 2.6539 - val_loss: 6.9342 - val_y1_output_loss: 2.8652 - val_y2_output_loss: 4.4972 - val_y1_output_root_mean_squared_error: 1.6128 - val_y2_output_root_mean_squared_error: 2.0816
# Epoch 34/500
# 614/614 [==============================] - 0s 162us/sample - loss: 8.4976 - y1_output_loss: 3.0436 - y2_output_loss: 5.3980 - y1_output_root_mean_squared_error: 1.7523 - y2_output_root_mean_squared_error: 2.3296 - val_loss: 10.1289 - val_y1_output_loss: 3.5674 - val_y2_output_loss: 7.1659 - val_y1_output_root_mean_squared_error: 1.8222 - val_y2_output_root_mean_squared_error: 2.6093
# Epoch 35/500
# 614/614 [==============================] - 0s 156us/sample - loss: 10.3024 - y1_output_loss: 3.6279 - y2_output_loss: 6.6240 - y1_output_root_mean_squared_error: 1.9039 - y2_output_root_mean_squared_error: 2.5841 - val_loss: 7.3434 - val_y1_output_loss: 3.1768 - val_y2_output_loss: 4.6049 - val_y1_output_root_mean_squared_error: 1.7092 - val_y2_output_root_mean_squared_error: 2.1029
# Epoch 36/500
# 614/614 [==============================] - 0s 173us/sample - loss: 8.5464 - y1_output_loss: 2.8282 - y2_output_loss: 6.2079 - y1_output_root_mean_squared_error: 1.6454 - y2_output_root_mean_squared_error: 2.4164 - val_loss: 89.7908 - val_y1_output_loss: 25.8025 - val_y2_output_loss: 63.1644 - val_y1_output_root_mean_squared_error: 5.1421 - val_y2_output_root_mean_squared_error: 7.9592
# Epoch 37/500
# 614/614 [==============================] - 0s 156us/sample - loss: 10.7725 - y1_output_loss: 3.5732 - y2_output_loss: 7.2107 - y1_output_root_mean_squared_error: 1.8982 - y2_output_root_mean_squared_error: 2.6775 - val_loss: 23.7879 - val_y1_output_loss: 5.9679 - val_y2_output_loss: 17.7447 - val_y1_output_root_mean_squared_error: 2.3936 - val_y2_output_root_mean_squared_error: 4.2495
# Epoch 38/500
# 614/614 [==============================] - 0s 163us/sample - loss: 7.1459 - y1_output_loss: 2.5031 - y2_output_loss: 4.6350 - y1_output_root_mean_squared_error: 1.5792 - y2_output_root_mean_squared_error: 2.1568 - val_loss: 6.1408 - val_y1_output_loss: 2.4217 - val_y2_output_loss: 4.1631 - val_y1_output_root_mean_squared_error: 1.4834 - val_y2_output_root_mean_squared_error: 1.9850
# Epoch 39/500
# 614/614 [==============================] - 0s 168us/sample - loss: 7.9519 - y1_output_loss: 2.6863 - y2_output_loss: 5.2261 - y1_output_root_mean_squared_error: 1.6460 - y2_output_root_mean_squared_error: 2.2897 - val_loss: 9.4301 - val_y1_output_loss: 2.6105 - val_y2_output_loss: 6.9939 - val_y1_output_root_mean_squared_error: 1.5472 - val_y2_output_root_mean_squared_error: 2.6526
# Epoch 40/500
# 614/614 [==============================] - 0s 162us/sample - loss: 6.8234 - y1_output_loss: 2.2360 - y2_output_loss: 4.7103 - y1_output_root_mean_squared_error: 1.4740 - y2_output_root_mean_squared_error: 2.1565 - val_loss: 51.7951 - val_y1_output_loss: 17.5966 - val_y2_output_loss: 34.5756 - val_y1_output_root_mean_squared_error: 4.2064 - val_y2_output_root_mean_squared_error: 5.8396
# Epoch 41/500
# 614/614 [==============================] - 0s 170us/sample - loss: 8.2087 - y1_output_loss: 2.7088 - y2_output_loss: 5.5942 - y1_output_root_mean_squared_error: 1.6452 - y2_output_root_mean_squared_error: 2.3457 - val_loss: 8.2326 - val_y1_output_loss: 2.2190 - val_y2_output_loss: 6.2584 - val_y1_output_root_mean_squared_error: 1.4171 - val_y2_output_root_mean_squared_error: 2.4949
# Epoch 42/500
# 614/614 [==============================] - 0s 177us/sample - loss: 7.5770 - y1_output_loss: 2.3519 - y2_output_loss: 5.1584 - y1_output_root_mean_squared_error: 1.5407 - y2_output_root_mean_squared_error: 2.2811 - val_loss: 7.3099 - val_y1_output_loss: 2.2016 - val_y2_output_loss: 5.6180 - val_y1_output_root_mean_squared_error: 1.4361 - val_y2_output_root_mean_squared_error: 2.2908
# Epoch 43/500
# 614/614 [==============================] - 0s 166us/sample - loss: 7.4232 - y1_output_loss: 2.3531 - y2_output_loss: 5.0843 - y1_output_root_mean_squared_error: 1.5368 - y2_output_root_mean_squared_error: 2.2497 - val_loss: 13.0353 - val_y1_output_loss: 5.6195 - val_y2_output_loss: 7.4920 - val_y1_output_root_mean_squared_error: 2.3605 - val_y2_output_root_mean_squared_error: 2.7319
# Epoch 44/500
# 614/614 [==============================] - 0s 154us/sample - loss: 7.5362 - y1_output_loss: 2.4183 - y2_output_loss: 5.1298 - y1_output_root_mean_squared_error: 1.5400 - y2_output_root_mean_squared_error: 2.2726 - val_loss: 7.6345 - val_y1_output_loss: 3.2041 - val_y2_output_loss: 4.7274 - val_y1_output_root_mean_squared_error: 1.7663 - val_y2_output_root_mean_squared_error: 2.1248
# Epoch 45/500
# 614/614 [==============================] - 0s 154us/sample - loss: 8.9947 - y1_output_loss: 2.7737 - y2_output_loss: 6.1693 - y1_output_root_mean_squared_error: 1.6717 - y2_output_root_mean_squared_error: 2.4900 - val_loss: 7.5146 - val_y1_output_loss: 1.8688 - val_y2_output_loss: 6.1312 - val_y1_output_root_mean_squared_error: 1.2990 - val_y2_output_root_mean_squared_error: 2.4139
# Epoch 46/500
# 614/614 [==============================] - 0s 162us/sample - loss: 6.9720 - y1_output_loss: 2.2540 - y2_output_loss: 4.7817 - y1_output_root_mean_squared_error: 1.4961 - y2_output_root_mean_squared_error: 2.1757 - val_loss: 7.2217 - val_y1_output_loss: 2.3222 - val_y2_output_loss: 5.1108 - val_y1_output_root_mean_squared_error: 1.5093 - val_y2_output_root_mean_squared_error: 2.2234
# Epoch 47/500
# 614/614 [==============================] - 0s 160us/sample - loss: 5.7448 - y1_output_loss: 1.9341 - y2_output_loss: 3.8662 - y1_output_root_mean_squared_error: 1.3747 - y2_output_root_mean_squared_error: 1.9635 - val_loss: 8.2306 - val_y1_output_loss: 2.6616 - val_y2_output_loss: 5.9086 - val_y1_output_root_mean_squared_error: 1.6039 - val_y2_output_root_mean_squared_error: 2.3787
# Epoch 48/500
# 614/614 [==============================] - 0s 163us/sample - loss: 5.9423 - y1_output_loss: 1.8422 - y2_output_loss: 4.0687 - y1_output_root_mean_squared_error: 1.3626 - y2_output_root_mean_squared_error: 2.0213 - val_loss: 4.9371 - val_y1_output_loss: 1.7764 - val_y2_output_loss: 3.4317 - val_y1_output_root_mean_squared_error: 1.2756 - val_y2_output_root_mean_squared_error: 1.8194
# Epoch 49/500
# 614/614 [==============================] - 0s 155us/sample - loss: 7.5712 - y1_output_loss: 2.3013 - y2_output_loss: 5.2434 - y1_output_root_mean_squared_error: 1.5169 - y2_output_root_mean_squared_error: 2.2957 - val_loss: 5.1415 - val_y1_output_loss: 1.6529 - val_y2_output_loss: 3.8150 - val_y1_output_root_mean_squared_error: 1.2302 - val_y2_output_root_mean_squared_error: 1.9047
# Epoch 50/500
# 614/614 [==============================] - 0s 155us/sample - loss: 6.4313 - y1_output_loss: 1.8702 - y2_output_loss: 4.5372 - y1_output_root_mean_squared_error: 1.3722 - y2_output_root_mean_squared_error: 2.1327 - val_loss: 5.1004 - val_y1_output_loss: 1.8190 - val_y2_output_loss: 3.4058 - val_y1_output_root_mean_squared_error: 1.2980 - val_y2_output_root_mean_squared_error: 1.8481
# Epoch 51/500
# 614/614 [==============================] - 0s 158us/sample - loss: 6.0953 - y1_output_loss: 1.8777 - y2_output_loss: 4.2104 - y1_output_root_mean_squared_error: 1.3610 - y2_output_root_mean_squared_error: 2.0599 - val_loss: 6.7575 - val_y1_output_loss: 2.1305 - val_y2_output_loss: 5.0581 - val_y1_output_root_mean_squared_error: 1.4209 - val_y2_output_root_mean_squared_error: 2.1768
# Epoch 52/500
# 614/614 [==============================] - 0s 169us/sample - loss: 6.1295 - y1_output_loss: 1.7931 - y2_output_loss: 4.3099 - y1_output_root_mean_squared_error: 1.3449 - y2_output_root_mean_squared_error: 2.0786 - val_loss: 4.7486 - val_y1_output_loss: 1.5981 - val_y2_output_loss: 3.3468 - val_y1_output_root_mean_squared_error: 1.2117 - val_y2_output_root_mean_squared_error: 1.8112
# Epoch 53/500
# 614/614 [==============================] - 0s 161us/sample - loss: 5.6253 - y1_output_loss: 1.6772 - y2_output_loss: 3.9459 - y1_output_root_mean_squared_error: 1.2970 - y2_output_root_mean_squared_error: 1.9857 - val_loss: 4.8178 - val_y1_output_loss: 1.5801 - val_y2_output_loss: 3.6800 - val_y1_output_root_mean_squared_error: 1.1908 - val_y2_output_root_mean_squared_error: 1.8439
# Epoch 54/500
# 614/614 [==============================] - 0s 165us/sample - loss: 7.0410 - y1_output_loss: 2.1505 - y2_output_loss: 4.9376 - y1_output_root_mean_squared_error: 1.4619 - y2_output_root_mean_squared_error: 2.2145 - val_loss: 5.7780 - val_y1_output_loss: 2.3554 - val_y2_output_loss: 3.6867 - val_y1_output_root_mean_squared_error: 1.4951 - val_y2_output_root_mean_squared_error: 1.8822
# Epoch 55/500
# 614/614 [==============================] - 0s 153us/sample - loss: 9.0965 - y1_output_loss: 2.6117 - y2_output_loss: 6.4693 - y1_output_root_mean_squared_error: 1.6170 - y2_output_root_mean_squared_error: 2.5460 - val_loss: 8.8816 - val_y1_output_loss: 3.4431 - val_y2_output_loss: 5.5012 - val_y1_output_root_mean_squared_error: 1.8255 - val_y2_output_root_mean_squared_error: 2.3557
# Epoch 56/500
# 614/614 [==============================] - 0s 162us/sample - loss: 5.4066 - y1_output_loss: 1.7318 - y2_output_loss: 3.7550 - y1_output_root_mean_squared_error: 1.3089 - y2_output_root_mean_squared_error: 1.9218 - val_loss: 28.9940 - val_y1_output_loss: 7.3246 - val_y2_output_loss: 21.1981 - val_y1_output_root_mean_squared_error: 2.6933 - val_y2_output_root_mean_squared_error: 4.6627
# Epoch 57/500
# 614/614 [==============================] - 0s 159us/sample - loss: 5.3591 - y1_output_loss: 1.6592 - y2_output_loss: 3.6870 - y1_output_root_mean_squared_error: 1.2807 - y2_output_root_mean_squared_error: 1.9284 - val_loss: 5.8752 - val_y1_output_loss: 2.5701 - val_y2_output_loss: 3.4079 - val_y1_output_root_mean_squared_error: 1.5703 - val_y2_output_root_mean_squared_error: 1.8464
# Epoch 58/500
# 614/614 [==============================] - 0s 160us/sample - loss: 5.4091 - y1_output_loss: 1.6194 - y2_output_loss: 3.8113 - y1_output_root_mean_squared_error: 1.2717 - y2_output_root_mean_squared_error: 1.9473 - val_loss: 4.4406 - val_y1_output_loss: 1.5914 - val_y2_output_loss: 3.0356 - val_y1_output_root_mean_squared_error: 1.2122 - val_y2_output_root_mean_squared_error: 1.7237
# Epoch 59/500
# 614/614 [==============================] - 0s 157us/sample - loss: 6.3343 - y1_output_loss: 1.9003 - y2_output_loss: 4.3914 - y1_output_root_mean_squared_error: 1.3826 - y2_output_root_mean_squared_error: 2.1030 - val_loss: 5.7838 - val_y1_output_loss: 2.0114 - val_y2_output_loss: 3.8826 - val_y1_output_root_mean_squared_error: 1.3731 - val_y2_output_root_mean_squared_error: 1.9744
# Epoch 60/500
# 614/614 [==============================] - 0s 161us/sample - loss: 4.7571 - y1_output_loss: 1.4238 - y2_output_loss: 3.3388 - y1_output_root_mean_squared_error: 1.1979 - y2_output_root_mean_squared_error: 1.8227 - val_loss: 4.8830 - val_y1_output_loss: 1.2416 - val_y2_output_loss: 3.6717 - val_y1_output_root_mean_squared_error: 1.0803 - val_y2_output_root_mean_squared_error: 1.9276
# Epoch 61/500
# 614/614 [==============================] - 0s 173us/sample - loss: 4.7528 - y1_output_loss: 1.4679 - y2_output_loss: 3.3347 - y1_output_root_mean_squared_error: 1.2140 - y2_output_root_mean_squared_error: 1.8108 - val_loss: 9.4805 - val_y1_output_loss: 1.5069 - val_y2_output_loss: 7.9473 - val_y1_output_root_mean_squared_error: 1.1727 - val_y2_output_root_mean_squared_error: 2.8470
# Epoch 62/500
# 614/614 [==============================] - 0s 154us/sample - loss: 5.4250 - y1_output_loss: 1.5364 - y2_output_loss: 3.8612 - y1_output_root_mean_squared_error: 1.2442 - y2_output_root_mean_squared_error: 1.9690 - val_loss: 9.9037 - val_y1_output_loss: 2.6466 - val_y2_output_loss: 7.2041 - val_y1_output_root_mean_squared_error: 1.5953 - val_y2_output_root_mean_squared_error: 2.7127
# Epoch 63/500
# 614/614 [==============================] - 0s 172us/sample - loss: 7.8191 - y1_output_loss: 2.4879 - y2_output_loss: 5.3081 - y1_output_root_mean_squared_error: 1.5839 - y2_output_root_mean_squared_error: 2.3044 - val_loss: 10.2058 - val_y1_output_loss: 2.4465 - val_y2_output_loss: 7.7059 - val_y1_output_root_mean_squared_error: 1.5327 - val_y2_output_root_mean_squared_error: 2.8030
# Epoch 64/500
# 614/614 [==============================] - 0s 169us/sample - loss: 4.6648 - y1_output_loss: 1.4059 - y2_output_loss: 3.2339 - y1_output_root_mean_squared_error: 1.1871 - y2_output_root_mean_squared_error: 1.8043 - val_loss: 5.8216 - val_y1_output_loss: 1.6191 - val_y2_output_loss: 4.2783 - val_y1_output_root_mean_squared_error: 1.2288 - val_y2_output_root_mean_squared_error: 2.0765
# Epoch 65/500
# 614/614 [==============================] - 0s 168us/sample - loss: 4.2432 - y1_output_loss: 1.2245 - y2_output_loss: 3.0594 - y1_output_root_mean_squared_error: 1.1101 - y2_output_root_mean_squared_error: 1.7352 - val_loss: 4.9497 - val_y1_output_loss: 1.6962 - val_y2_output_loss: 3.5211 - val_y1_output_root_mean_squared_error: 1.2752 - val_y2_output_root_mean_squared_error: 1.8231
# Epoch 66/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.8630 - y1_output_loss: 1.1186 - y2_output_loss: 2.7117 - y1_output_root_mean_squared_error: 1.0613 - y2_output_root_mean_squared_error: 1.6542 - val_loss: 4.7007 - val_y1_output_loss: 1.9421 - val_y2_output_loss: 2.8178 - val_y1_output_root_mean_squared_error: 1.3644 - val_y2_output_root_mean_squared_error: 1.6850
# Epoch 67/500
# 614/614 [==============================] - 0s 155us/sample - loss: 4.1104 - y1_output_loss: 1.0762 - y2_output_loss: 3.0194 - y1_output_root_mean_squared_error: 1.0397 - y2_output_root_mean_squared_error: 1.7405 - val_loss: 4.3565 - val_y1_output_loss: 1.0025 - val_y2_output_loss: 3.6676 - val_y1_output_root_mean_squared_error: 0.9634 - val_y2_output_root_mean_squared_error: 1.8516
# Epoch 68/500
# 614/614 [==============================] - 0s 158us/sample - loss: 3.5728 - y1_output_loss: 1.0285 - y2_output_loss: 2.5463 - y1_output_root_mean_squared_error: 1.0116 - y2_output_root_mean_squared_error: 1.5967 - val_loss: 8.2023 - val_y1_output_loss: 3.5031 - val_y2_output_loss: 4.6679 - val_y1_output_root_mean_squared_error: 1.8611 - val_y2_output_root_mean_squared_error: 2.1769
# Epoch 69/500
# 614/614 [==============================] - 0s 171us/sample - loss: 6.4088 - y1_output_loss: 1.9534 - y2_output_loss: 4.4062 - y1_output_root_mean_squared_error: 1.4034 - y2_output_root_mean_squared_error: 2.1070 - val_loss: 4.0136 - val_y1_output_loss: 1.5195 - val_y2_output_loss: 2.6032 - val_y1_output_root_mean_squared_error: 1.2050 - val_y2_output_root_mean_squared_error: 1.6005
# Epoch 70/500
# 614/614 [==============================] - 0s 172us/sample - loss: 3.6815 - y1_output_loss: 1.0108 - y2_output_loss: 2.7499 - y1_output_root_mean_squared_error: 1.0021 - y2_output_root_mean_squared_error: 1.6363 - val_loss: 16.7943 - val_y1_output_loss: 4.4918 - val_y2_output_loss: 12.1437 - val_y1_output_root_mean_squared_error: 2.0929 - val_y2_output_root_mean_squared_error: 3.5234
# Epoch 71/500
# 614/614 [==============================] - 0s 192us/sample - loss: 4.9786 - y1_output_loss: 1.3402 - y2_output_loss: 3.6228 - y1_output_root_mean_squared_error: 1.1610 - y2_output_root_mean_squared_error: 1.9055 - val_loss: 4.3148 - val_y1_output_loss: 1.1327 - val_y2_output_loss: 3.4714 - val_y1_output_root_mean_squared_error: 1.0367 - val_y2_output_root_mean_squared_error: 1.8000
# Epoch 72/500
# 614/614 [==============================] - 0s 165us/sample - loss: 4.0659 - y1_output_loss: 1.0910 - y2_output_loss: 2.9740 - y1_output_root_mean_squared_error: 1.0434 - y2_output_root_mean_squared_error: 1.7255 - val_loss: 3.0975 - val_y1_output_loss: 0.8850 - val_y2_output_loss: 2.3085 - val_y1_output_root_mean_squared_error: 0.9150 - val_y2_output_root_mean_squared_error: 1.5034
# Epoch 73/500
# 614/614 [==============================] - 0s 155us/sample - loss: 4.3305 - y1_output_loss: 1.0997 - y2_output_loss: 3.1938 - y1_output_root_mean_squared_error: 1.0532 - y2_output_root_mean_squared_error: 1.7948 - val_loss: 4.0280 - val_y1_output_loss: 1.3735 - val_y2_output_loss: 2.6627 - val_y1_output_root_mean_squared_error: 1.1484 - val_y2_output_root_mean_squared_error: 1.6460
# Epoch 74/500
# 614/614 [==============================] - 0s 178us/sample - loss: 3.3296 - y1_output_loss: 0.9289 - y2_output_loss: 2.3743 - y1_output_root_mean_squared_error: 0.9663 - y2_output_root_mean_squared_error: 1.5478 - val_loss: 3.8382 - val_y1_output_loss: 1.2628 - val_y2_output_loss: 2.6450 - val_y1_output_root_mean_squared_error: 1.0842 - val_y2_output_root_mean_squared_error: 1.6318
# Epoch 75/500
# 614/614 [==============================] - 0s 161us/sample - loss: 3.2532 - y1_output_loss: 0.9199 - y2_output_loss: 2.4202 - y1_output_root_mean_squared_error: 0.9569 - y2_output_root_mean_squared_error: 1.5289 - val_loss: 10.1995 - val_y1_output_loss: 1.5023 - val_y2_output_loss: 8.9480 - val_y1_output_root_mean_squared_error: 1.2139 - val_y2_output_root_mean_squared_error: 2.9540
# Epoch 76/500
# 614/614 [==============================] - 0s 169us/sample - loss: 3.7309 - y1_output_loss: 1.0992 - y2_output_loss: 2.6219 - y1_output_root_mean_squared_error: 1.0507 - y2_output_root_mean_squared_error: 1.6207 - val_loss: 3.2180 - val_y1_output_loss: 1.2015 - val_y2_output_loss: 2.1432 - val_y1_output_root_mean_squared_error: 1.0740 - val_y2_output_root_mean_squared_error: 1.4368
# Epoch 77/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.5708 - y1_output_loss: 1.0056 - y2_output_loss: 2.5521 - y1_output_root_mean_squared_error: 1.0049 - y2_output_root_mean_squared_error: 1.6003 - val_loss: 8.2176 - val_y1_output_loss: 1.1547 - val_y2_output_loss: 7.3658 - val_y1_output_root_mean_squared_error: 1.0658 - val_y2_output_root_mean_squared_error: 2.6611
# Epoch 78/500
# 614/614 [==============================] - 0s 158us/sample - loss: 3.8181 - y1_output_loss: 1.1894 - y2_output_loss: 2.6169 - y1_output_root_mean_squared_error: 1.0894 - y2_output_root_mean_squared_error: 1.6222 - val_loss: 2.6738 - val_y1_output_loss: 0.7631 - val_y2_output_loss: 2.0467 - val_y1_output_root_mean_squared_error: 0.8478 - val_y2_output_root_mean_squared_error: 1.3982
# Epoch 79/500
# 614/614 [==============================] - 0s 159us/sample - loss: 2.8944 - y1_output_loss: 0.7797 - y2_output_loss: 2.0972 - y1_output_root_mean_squared_error: 0.8858 - y2_output_root_mean_squared_error: 1.4525 - val_loss: 2.7730 - val_y1_output_loss: 0.9290 - val_y2_output_loss: 1.8713 - val_y1_output_root_mean_squared_error: 0.9408 - val_y2_output_root_mean_squared_error: 1.3740
# Epoch 80/500
# 614/614 [==============================] - 0s 170us/sample - loss: 3.7570 - y1_output_loss: 1.0948 - y2_output_loss: 2.6410 - y1_output_root_mean_squared_error: 1.0478 - y2_output_root_mean_squared_error: 1.6307 - val_loss: 2.7061 - val_y1_output_loss: 0.8621 - val_y2_output_loss: 1.8968 - val_y1_output_root_mean_squared_error: 0.9195 - val_y2_output_root_mean_squared_error: 1.3640
# Epoch 81/500
# 614/614 [==============================] - 0s 170us/sample - loss: 5.0255 - y1_output_loss: 1.3113 - y2_output_loss: 3.6943 - y1_output_root_mean_squared_error: 1.1460 - y2_output_root_mean_squared_error: 1.9267 - val_loss: 5.3003 - val_y1_output_loss: 1.2432 - val_y2_output_loss: 3.9538 - val_y1_output_root_mean_squared_error: 1.1013 - val_y2_output_root_mean_squared_error: 2.0218
# Epoch 82/500
# 614/614 [==============================] - 0s 162us/sample - loss: 3.3148 - y1_output_loss: 0.9534 - y2_output_loss: 2.3670 - y1_output_root_mean_squared_error: 0.9746 - y2_output_root_mean_squared_error: 1.5379 - val_loss: 4.7524 - val_y1_output_loss: 1.5442 - val_y2_output_loss: 3.1174 - val_y1_output_root_mean_squared_error: 1.2341 - val_y2_output_root_mean_squared_error: 1.7970
# Epoch 83/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.9071 - y1_output_loss: 0.7316 - y2_output_loss: 2.1607 - y1_output_root_mean_squared_error: 0.8561 - y2_output_root_mean_squared_error: 1.4745 - val_loss: 4.1600 - val_y1_output_loss: 1.0061 - val_y2_output_loss: 3.2569 - val_y1_output_root_mean_squared_error: 1.0022 - val_y2_output_root_mean_squared_error: 1.7764
# Epoch 84/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.7185 - y1_output_loss: 1.0289 - y2_output_loss: 2.6921 - y1_output_root_mean_squared_error: 1.0076 - y2_output_root_mean_squared_error: 1.6442 - val_loss: 6.3359 - val_y1_output_loss: 2.5005 - val_y2_output_loss: 3.8474 - val_y1_output_root_mean_squared_error: 1.5921 - val_y2_output_root_mean_squared_error: 1.9496
# Epoch 85/500
# 614/614 [==============================] - 0s 171us/sample - loss: 4.2453 - y1_output_loss: 1.1242 - y2_output_loss: 3.0849 - y1_output_root_mean_squared_error: 1.0650 - y2_output_root_mean_squared_error: 1.7638 - val_loss: 2.5116 - val_y1_output_loss: 0.7208 - val_y2_output_loss: 1.8741 - val_y1_output_root_mean_squared_error: 0.8437 - val_y2_output_root_mean_squared_error: 1.3416
# Epoch 86/500
# 614/614 [==============================] - 0s 171us/sample - loss: 2.8695 - y1_output_loss: 0.6659 - y2_output_loss: 2.1924 - y1_output_root_mean_squared_error: 0.8181 - y2_output_root_mean_squared_error: 1.4833 - val_loss: 2.5824 - val_y1_output_loss: 0.6419 - val_y2_output_loss: 1.9244 - val_y1_output_root_mean_squared_error: 0.7849 - val_y2_output_root_mean_squared_error: 1.4023
# Epoch 87/500
# 614/614 [==============================] - 0s 171us/sample - loss: 3.0932 - y1_output_loss: 0.7326 - y2_output_loss: 2.3437 - y1_output_root_mean_squared_error: 0.8592 - y2_output_root_mean_squared_error: 1.5346 - val_loss: 2.4639 - val_y1_output_loss: 0.7104 - val_y2_output_loss: 1.7310 - val_y1_output_root_mean_squared_error: 0.8284 - val_y2_output_root_mean_squared_error: 1.3333
# Epoch 88/500
# 614/614 [==============================] - 0s 169us/sample - loss: 3.9779 - y1_output_loss: 1.0854 - y2_output_loss: 2.8608 - y1_output_root_mean_squared_error: 1.0459 - y2_output_root_mean_squared_error: 1.6983 - val_loss: 4.4708 - val_y1_output_loss: 1.7140 - val_y2_output_loss: 2.7194 - val_y1_output_root_mean_squared_error: 1.2964 - val_y2_output_root_mean_squared_error: 1.6704
# Epoch 89/500
# 614/614 [==============================] - 0s 160us/sample - loss: 2.8458 - y1_output_loss: 0.7579 - y2_output_loss: 2.0945 - y1_output_root_mean_squared_error: 0.8735 - y2_output_root_mean_squared_error: 1.4432 - val_loss: 3.3382 - val_y1_output_loss: 0.7580 - val_y2_output_loss: 2.7595 - val_y1_output_root_mean_squared_error: 0.8638 - val_y2_output_root_mean_squared_error: 1.6100
# Epoch 90/500
# 614/614 [==============================] - 0s 167us/sample - loss: 3.2772 - y1_output_loss: 0.8880 - y2_output_loss: 2.4395 - y1_output_root_mean_squared_error: 0.9407 - y2_output_root_mean_squared_error: 1.5467 - val_loss: 6.0723 - val_y1_output_loss: 0.8752 - val_y2_output_loss: 5.2787 - val_y1_output_root_mean_squared_error: 0.9278 - val_y2_output_root_mean_squared_error: 2.2829
# Epoch 91/500
# 614/614 [==============================] - 0s 177us/sample - loss: 2.7443 - y1_output_loss: 0.6276 - y2_output_loss: 2.1194 - y1_output_root_mean_squared_error: 0.7904 - y2_output_root_mean_squared_error: 1.4559 - val_loss: 5.2913 - val_y1_output_loss: 1.0510 - val_y2_output_loss: 4.3046 - val_y1_output_root_mean_squared_error: 1.0294 - val_y2_output_root_mean_squared_error: 2.0571
# Epoch 92/500
# 614/614 [==============================] - 0s 182us/sample - loss: 2.8700 - y1_output_loss: 0.7056 - y2_output_loss: 2.1739 - y1_output_root_mean_squared_error: 0.8302 - y2_output_root_mean_squared_error: 1.4768 - val_loss: 7.1339 - val_y1_output_loss: 2.8848 - val_y2_output_loss: 4.3651 - val_y1_output_root_mean_squared_error: 1.7019 - val_y2_output_root_mean_squared_error: 2.0585
# Epoch 93/500
# 614/614 [==============================] - 0s 172us/sample - loss: 2.2428 - y1_output_loss: 0.5825 - y2_output_loss: 1.6678 - y1_output_root_mean_squared_error: 0.7612 - y2_output_root_mean_squared_error: 1.2897 - val_loss: 3.8808 - val_y1_output_loss: 1.6533 - val_y2_output_loss: 2.1919 - val_y1_output_root_mean_squared_error: 1.2899 - val_y2_output_root_mean_squared_error: 1.4890
# Epoch 94/500
# 614/614 [==============================] - 0s 163us/sample - loss: 2.3703 - y1_output_loss: 0.6037 - y2_output_loss: 1.7695 - y1_output_root_mean_squared_error: 0.7754 - y2_output_root_mean_squared_error: 1.3301 - val_loss: 8.4508 - val_y1_output_loss: 3.3267 - val_y2_output_loss: 4.9786 - val_y1_output_root_mean_squared_error: 1.8496 - val_y2_output_root_mean_squared_error: 2.2427
# Epoch 95/500
# 614/614 [==============================] - 0s 160us/sample - loss: 6.3031 - y1_output_loss: 1.7875 - y2_output_loss: 4.6576 - y1_output_root_mean_squared_error: 1.3272 - y2_output_root_mean_squared_error: 2.1311 - val_loss: 10.3636 - val_y1_output_loss: 2.1963 - val_y2_output_loss: 7.8222 - val_y1_output_root_mean_squared_error: 1.5025 - val_y2_output_root_mean_squared_error: 2.8471
# Epoch 96/500
# 614/614 [==============================] - 0s 157us/sample - loss: 2.9444 - y1_output_loss: 0.7612 - y2_output_loss: 2.1695 - y1_output_root_mean_squared_error: 0.8754 - y2_output_root_mean_squared_error: 1.4758 - val_loss: 2.8355 - val_y1_output_loss: 1.0037 - val_y2_output_loss: 1.8735 - val_y1_output_root_mean_squared_error: 1.0021 - val_y2_output_root_mean_squared_error: 1.3532
# Epoch 97/500
# 614/614 [==============================] - 0s 164us/sample - loss: 2.8680 - y1_output_loss: 0.7161 - y2_output_loss: 2.1306 - y1_output_root_mean_squared_error: 0.8494 - y2_output_root_mean_squared_error: 1.4651 - val_loss: 2.0479 - val_y1_output_loss: 0.5002 - val_y2_output_loss: 1.5597 - val_y1_output_root_mean_squared_error: 0.6990 - val_y2_output_root_mean_squared_error: 1.2488
# Epoch 98/500
# 614/614 [==============================] - 0s 168us/sample - loss: 2.6053 - y1_output_loss: 0.5812 - y2_output_loss: 2.0152 - y1_output_root_mean_squared_error: 0.7640 - y2_output_root_mean_squared_error: 1.4218 - val_loss: 2.5318 - val_y1_output_loss: 0.7087 - val_y2_output_loss: 1.8848 - val_y1_output_root_mean_squared_error: 0.8325 - val_y2_output_root_mean_squared_error: 1.3560
# Epoch 99/500
# 614/614 [==============================] - 0s 163us/sample - loss: 2.7010 - y1_output_loss: 0.6748 - y2_output_loss: 2.0292 - y1_output_root_mean_squared_error: 0.8123 - y2_output_root_mean_squared_error: 1.4287 - val_loss: 5.2121 - val_y1_output_loss: 1.7862 - val_y2_output_loss: 3.5079 - val_y1_output_root_mean_squared_error: 1.3356 - val_y2_output_root_mean_squared_error: 1.8516
# Epoch 100/500
# 614/614 [==============================] - 0s 174us/sample - loss: 2.2869 - y1_output_loss: 0.5671 - y2_output_loss: 1.7382 - y1_output_root_mean_squared_error: 0.7521 - y2_output_root_mean_squared_error: 1.3120 - val_loss: 8.4924 - val_y1_output_loss: 1.5338 - val_y2_output_loss: 6.7427 - val_y1_output_root_mean_squared_error: 1.2356 - val_y2_output_root_mean_squared_error: 2.6393
# Epoch 101/500
# 614/614 [==============================] - 0s 185us/sample - loss: 2.5878 - y1_output_loss: 0.6541 - y2_output_loss: 1.9280 - y1_output_root_mean_squared_error: 0.8123 - y2_output_root_mean_squared_error: 1.3885 - val_loss: 2.3683 - val_y1_output_loss: 0.5760 - val_y2_output_loss: 1.7637 - val_y1_output_root_mean_squared_error: 0.7537 - val_y2_output_root_mean_squared_error: 1.3417
# Epoch 102/500
# 614/614 [==============================] - 0s 161us/sample - loss: 2.5459 - y1_output_loss: 0.6446 - y2_output_loss: 1.8969 - y1_output_root_mean_squared_error: 0.8057 - y2_output_root_mean_squared_error: 1.3772 - val_loss: 5.4800 - val_y1_output_loss: 1.5397 - val_y2_output_loss: 3.9088 - val_y1_output_root_mean_squared_error: 1.2549 - val_y2_output_root_mean_squared_error: 1.9762
# Epoch 103/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.4939 - y1_output_loss: 0.6140 - y2_output_loss: 1.9315 - y1_output_root_mean_squared_error: 0.7859 - y2_output_root_mean_squared_error: 1.3698 - val_loss: 8.0793 - val_y1_output_loss: 0.9375 - val_y2_output_loss: 6.9199 - val_y1_output_root_mean_squared_error: 0.9726 - val_y2_output_root_mean_squared_error: 2.6708
# Epoch 104/500
# 614/614 [==============================] - 0s 158us/sample - loss: 2.1483 - y1_output_loss: 0.5638 - y2_output_loss: 1.6179 - y1_output_root_mean_squared_error: 0.7511 - y2_output_root_mean_squared_error: 1.2586 - val_loss: 3.4603 - val_y1_output_loss: 0.4088 - val_y2_output_loss: 2.9694 - val_y1_output_root_mean_squared_error: 0.6312 - val_y2_output_root_mean_squared_error: 1.7498
# Epoch 105/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.8098 - y1_output_loss: 0.7080 - y2_output_loss: 2.1233 - y1_output_root_mean_squared_error: 0.8326 - y2_output_root_mean_squared_error: 1.4548 - val_loss: 6.0628 - val_y1_output_loss: 1.6208 - val_y2_output_loss: 4.5415 - val_y1_output_root_mean_squared_error: 1.2810 - val_y2_output_root_mean_squared_error: 2.1029
# Epoch 106/500
# 614/614 [==============================] - 0s 177us/sample - loss: 1.8902 - y1_output_loss: 0.4927 - y2_output_loss: 1.3916 - y1_output_root_mean_squared_error: 0.7023 - y2_output_root_mean_squared_error: 1.1819 - val_loss: 2.3600 - val_y1_output_loss: 0.6469 - val_y2_output_loss: 1.6611 - val_y1_output_root_mean_squared_error: 0.8055 - val_y2_output_root_mean_squared_error: 1.3081
# Epoch 107/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.0445 - y1_output_loss: 0.8834 - y2_output_loss: 2.1385 - y1_output_root_mean_squared_error: 0.9426 - y2_output_root_mean_squared_error: 1.4683 - val_loss: 2.4201 - val_y1_output_loss: 0.7812 - val_y2_output_loss: 1.6611 - val_y1_output_root_mean_squared_error: 0.8813 - val_y2_output_root_mean_squared_error: 1.2820
# Epoch 108/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.1408 - y1_output_loss: 0.7852 - y2_output_loss: 2.3553 - y1_output_root_mean_squared_error: 0.8857 - y2_output_root_mean_squared_error: 1.5350 - val_loss: 2.5336 - val_y1_output_loss: 0.4759 - val_y2_output_loss: 2.1432 - val_y1_output_root_mean_squared_error: 0.6906 - val_y2_output_root_mean_squared_error: 1.4341
# Epoch 109/500
# 614/614 [==============================] - 0s 158us/sample - loss: 2.1331 - y1_output_loss: 0.5323 - y2_output_loss: 1.6248 - y1_output_root_mean_squared_error: 0.7283 - y2_output_root_mean_squared_error: 1.2660 - val_loss: 2.5339 - val_y1_output_loss: 0.9411 - val_y2_output_loss: 1.5705 - val_y1_output_root_mean_squared_error: 0.9764 - val_y2_output_root_mean_squared_error: 1.2572
# Epoch 110/500
# 614/614 [==============================] - 0s 153us/sample - loss: 1.9768 - y1_output_loss: 0.5095 - y2_output_loss: 1.5193 - y1_output_root_mean_squared_error: 0.7167 - y2_output_root_mean_squared_error: 1.2096 - val_loss: 8.0155 - val_y1_output_loss: 1.0878 - val_y2_output_loss: 6.8472 - val_y1_output_root_mean_squared_error: 1.0311 - val_y2_output_root_mean_squared_error: 2.6367
# Epoch 111/500
# 614/614 [==============================] - 0s 150us/sample - loss: 2.5690 - y1_output_loss: 0.5433 - y2_output_loss: 2.0028 - y1_output_root_mean_squared_error: 0.7402 - y2_output_root_mean_squared_error: 1.4217 - val_loss: 1.9432 - val_y1_output_loss: 0.4512 - val_y2_output_loss: 1.4953 - val_y1_output_root_mean_squared_error: 0.6688 - val_y2_output_root_mean_squared_error: 1.2231
# Epoch 112/500
# 614/614 [==============================] - 0s 163us/sample - loss: 2.9286 - y1_output_loss: 0.7935 - y2_output_loss: 2.1628 - y1_output_root_mean_squared_error: 0.8883 - y2_output_root_mean_squared_error: 1.4627 - val_loss: 3.9724 - val_y1_output_loss: 1.2619 - val_y2_output_loss: 2.7550 - val_y1_output_root_mean_squared_error: 1.1212 - val_y2_output_root_mean_squared_error: 1.6478
# Epoch 113/500
# 614/614 [==============================] - 0s 150us/sample - loss: 3.1818 - y1_output_loss: 0.8881 - y2_output_loss: 2.2738 - y1_output_root_mean_squared_error: 0.9467 - y2_output_root_mean_squared_error: 1.5118 - val_loss: 1.9966 - val_y1_output_loss: 0.5313 - val_y2_output_loss: 1.4317 - val_y1_output_root_mean_squared_error: 0.7295 - val_y2_output_root_mean_squared_error: 1.2101
# Epoch 114/500
# 614/614 [==============================] - 0s 154us/sample - loss: 1.8437 - y1_output_loss: 0.4612 - y2_output_loss: 1.3977 - y1_output_root_mean_squared_error: 0.6787 - y2_output_root_mean_squared_error: 1.1760 - val_loss: 5.8973 - val_y1_output_loss: 0.8905 - val_y2_output_loss: 5.0979 - val_y1_output_root_mean_squared_error: 0.9473 - val_y2_output_root_mean_squared_error: 2.2360
# Epoch 115/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.6206 - y1_output_loss: 0.6266 - y2_output_loss: 1.9838 - y1_output_root_mean_squared_error: 0.7915 - y2_output_root_mean_squared_error: 1.4121 - val_loss: 1.8264 - val_y1_output_loss: 0.3835 - val_y2_output_loss: 1.4779 - val_y1_output_root_mean_squared_error: 0.6137 - val_y2_output_root_mean_squared_error: 1.2040
# Epoch 116/500
# 614/614 [==============================] - 0s 160us/sample - loss: 4.1061 - y1_output_loss: 1.2301 - y2_output_loss: 2.8564 - y1_output_root_mean_squared_error: 1.1124 - y2_output_root_mean_squared_error: 1.6937 - val_loss: 2.7108 - val_y1_output_loss: 0.7294 - val_y2_output_loss: 2.0743 - val_y1_output_root_mean_squared_error: 0.8514 - val_y2_output_root_mean_squared_error: 1.4092
# Epoch 117/500
# 614/614 [==============================] - 0s 152us/sample - loss: 2.0491 - y1_output_loss: 0.5165 - y2_output_loss: 1.5331 - y1_output_root_mean_squared_error: 0.7213 - y2_output_root_mean_squared_error: 1.2365 - val_loss: 3.3720 - val_y1_output_loss: 0.4887 - val_y2_output_loss: 2.8801 - val_y1_output_root_mean_squared_error: 0.7059 - val_y2_output_root_mean_squared_error: 1.6952
# Epoch 118/500
# 614/614 [==============================] - 0s 156us/sample - loss: 1.9316 - y1_output_loss: 0.4150 - y2_output_loss: 1.5059 - y1_output_root_mean_squared_error: 0.6458 - y2_output_root_mean_squared_error: 1.2307 - val_loss: 2.7738 - val_y1_output_loss: 0.6386 - val_y2_output_loss: 2.1573 - val_y1_output_root_mean_squared_error: 0.7978 - val_y2_output_root_mean_squared_error: 1.4620
# Epoch 119/500
# 614/614 [==============================] - 0s 162us/sample - loss: 1.9132 - y1_output_loss: 0.4628 - y2_output_loss: 1.4683 - y1_output_root_mean_squared_error: 0.6751 - y2_output_root_mean_squared_error: 1.2072 - val_loss: 9.1638 - val_y1_output_loss: 2.9790 - val_y2_output_loss: 6.0439 - val_y1_output_root_mean_squared_error: 1.7523 - val_y2_output_root_mean_squared_error: 2.4684
# Epoch 120/500
# 614/614 [==============================] - 0s 161us/sample - loss: 2.2494 - y1_output_loss: 0.5340 - y2_output_loss: 1.7377 - y1_output_root_mean_squared_error: 0.7306 - y2_output_root_mean_squared_error: 1.3098 - val_loss: 5.3589 - val_y1_output_loss: 1.0948 - val_y2_output_loss: 4.4865 - val_y1_output_root_mean_squared_error: 1.0409 - val_y2_output_root_mean_squared_error: 2.0677
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.3337 - y1_output_loss: 0.1216 - y2_output_loss: 0.2114 - y1_output_root_mean_squared_error: 0.3485 - y2_output_root_mean_squared_error: 0.4607 - val_loss: 0.6152 - val_y1_output_loss: 0.1924 - val_y2_output_loss: 0.4241 - val_y1_output_root_mean_squared_error: 0.4370 - val_y2_output_root_mean_squared_error: 0.6513
# Epoch 462/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.3719 - y1_output_loss: 0.1220 - y2_output_loss: 0.2483 - y1_output_root_mean_squared_error: 0.3492 - y2_output_root_mean_squared_error: 0.5000 - val_loss: 0.7578 - val_y1_output_loss: 0.3189 - val_y2_output_loss: 0.4235 - val_y1_output_root_mean_squared_error: 0.5679 - val_y2_output_root_mean_squared_error: 0.6598
# Epoch 463/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.3454 - y1_output_loss: 0.1251 - y2_output_loss: 0.2185 - y1_output_root_mean_squared_error: 0.3554 - y2_output_root_mean_squared_error: 0.4681 - val_loss: 0.7905 - val_y1_output_loss: 0.2641 - val_y2_output_loss: 0.5136 - val_y1_output_root_mean_squared_error: 0.5159 - val_y2_output_root_mean_squared_error: 0.7241
# Epoch 464/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4158 - y1_output_loss: 0.1297 - y2_output_loss: 0.2841 - y1_output_root_mean_squared_error: 0.3602 - y2_output_root_mean_squared_error: 0.5348 - val_loss: 0.7854 - val_y1_output_loss: 0.2979 - val_y2_output_loss: 0.4950 - val_y1_output_root_mean_squared_error: 0.5442 - val_y2_output_root_mean_squared_error: 0.6995
# Epoch 465/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3860 - y1_output_loss: 0.1299 - y2_output_loss: 0.2538 - y1_output_root_mean_squared_error: 0.3618 - y2_output_root_mean_squared_error: 0.5050 - val_loss: 0.6238 - val_y1_output_loss: 0.2118 - val_y2_output_loss: 0.4068 - val_y1_output_root_mean_squared_error: 0.4556 - val_y2_output_root_mean_squared_error: 0.6452
# Epoch 466/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.3596 - y1_output_loss: 0.1145 - y2_output_loss: 0.2450 - y1_output_root_mean_squared_error: 0.3384 - y2_output_root_mean_squared_error: 0.4950 - val_loss: 0.7392 - val_y1_output_loss: 0.2598 - val_y2_output_loss: 0.4717 - val_y1_output_root_mean_squared_error: 0.5142 - val_y2_output_root_mean_squared_error: 0.6891
# Epoch 467/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.3621 - y1_output_loss: 0.1128 - y2_output_loss: 0.2580 - y1_output_root_mean_squared_error: 0.3332 - y2_output_root_mean_squared_error: 0.5011 - val_loss: 4.0090 - val_y1_output_loss: 1.3364 - val_y2_output_loss: 2.5340 - val_y1_output_root_mean_squared_error: 1.1773 - val_y2_output_root_mean_squared_error: 1.6195
# Epoch 468/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.4824 - y1_output_loss: 0.1511 - y2_output_loss: 0.3302 - y1_output_root_mean_squared_error: 0.3905 - y2_output_root_mean_squared_error: 0.5743 - val_loss: 0.6476 - val_y1_output_loss: 0.2071 - val_y2_output_loss: 0.4313 - val_y1_output_root_mean_squared_error: 0.4532 - val_y2_output_root_mean_squared_error: 0.6650
# Epoch 469/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.3443 - y1_output_loss: 0.1108 - y2_output_loss: 0.2375 - y1_output_root_mean_squared_error: 0.3306 - y2_output_root_mean_squared_error: 0.4847 - val_loss: 1.2185 - val_y1_output_loss: 0.2304 - val_y2_output_loss: 1.0369 - val_y1_output_root_mean_squared_error: 0.4708 - val_y2_output_root_mean_squared_error: 0.9984
# Epoch 470/500
# 614/614 [==============================] - 0s 170us/sample - loss: 0.3412 - y1_output_loss: 0.1232 - y2_output_loss: 0.2157 - y1_output_root_mean_squared_error: 0.3516 - y2_output_root_mean_squared_error: 0.4664 - val_loss: 0.5926 - val_y1_output_loss: 0.2194 - val_y2_output_loss: 0.3760 - val_y1_output_root_mean_squared_error: 0.4626 - val_y2_output_root_mean_squared_error: 0.6154
# Epoch 471/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.3971 - y1_output_loss: 0.1211 - y2_output_loss: 0.2781 - y1_output_root_mean_squared_error: 0.3495 - y2_output_root_mean_squared_error: 0.5244 - val_loss: 1.4164 - val_y1_output_loss: 0.3791 - val_y2_output_loss: 1.0038 - val_y1_output_root_mean_squared_error: 0.6235 - val_y2_output_root_mean_squared_error: 1.0138
# Epoch 472/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.3827 - y1_output_loss: 0.1182 - y2_output_loss: 0.2612 - y1_output_root_mean_squared_error: 0.3451 - y2_output_root_mean_squared_error: 0.5134 - val_loss: 0.5978 - val_y1_output_loss: 0.2060 - val_y2_output_loss: 0.3823 - val_y1_output_root_mean_squared_error: 0.4548 - val_y2_output_root_mean_squared_error: 0.6252
# Epoch 473/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.3360 - y1_output_loss: 0.1136 - y2_output_loss: 0.2265 - y1_output_root_mean_squared_error: 0.3373 - y2_output_root_mean_squared_error: 0.4714 - val_loss: 1.2335 - val_y1_output_loss: 0.2108 - val_y2_output_loss: 1.0126 - val_y1_output_root_mean_squared_error: 0.4624 - val_y2_output_root_mean_squared_error: 1.0098
# Epoch 474/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.4110 - y1_output_loss: 0.1139 - y2_output_loss: 0.2973 - y1_output_root_mean_squared_error: 0.3364 - y2_output_root_mean_squared_error: 0.5457 - val_loss: 0.7047 - val_y1_output_loss: 0.2755 - val_y2_output_loss: 0.4117 - val_y1_output_root_mean_squared_error: 0.5318 - val_y2_output_root_mean_squared_error: 0.6495
# Epoch 475/500
# 614/614 [==============================] - 0s 183us/sample - loss: 0.4685 - y1_output_loss: 0.1659 - y2_output_loss: 0.3002 - y1_output_root_mean_squared_error: 0.4087 - y2_output_root_mean_squared_error: 0.5491 - val_loss: 0.5775 - val_y1_output_loss: 0.1928 - val_y2_output_loss: 0.3757 - val_y1_output_root_mean_squared_error: 0.4405 - val_y2_output_root_mean_squared_error: 0.6192
# Epoch 476/500
# 614/614 [==============================] - 0s 164us/sample - loss: 0.4132 - y1_output_loss: 0.1283 - y2_output_loss: 0.2829 - y1_output_root_mean_squared_error: 0.3596 - y2_output_root_mean_squared_error: 0.5328 - val_loss: 0.8333 - val_y1_output_loss: 0.2661 - val_y2_output_loss: 0.5453 - val_y1_output_root_mean_squared_error: 0.5213 - val_y2_output_root_mean_squared_error: 0.7493
# Epoch 477/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.4025 - y1_output_loss: 0.1253 - y2_output_loss: 0.2772 - y1_output_root_mean_squared_error: 0.3551 - y2_output_root_mean_squared_error: 0.5257 - val_loss: 0.7155 - val_y1_output_loss: 0.2024 - val_y2_output_loss: 0.5016 - val_y1_output_root_mean_squared_error: 0.4502 - val_y2_output_root_mean_squared_error: 0.7161
# Epoch 478/500
# 614/614 [==============================] - 0s 187us/sample - loss: 0.4838 - y1_output_loss: 0.1184 - y2_output_loss: 0.3622 - y1_output_root_mean_squared_error: 0.3453 - y2_output_root_mean_squared_error: 0.6038 - val_loss: 0.6481 - val_y1_output_loss: 0.1958 - val_y2_output_loss: 0.4451 - val_y1_output_root_mean_squared_error: 0.4384 - val_y2_output_root_mean_squared_error: 0.6752
# Epoch 479/500
# 614/614 [==============================] - 0s 172us/sample - loss: 0.3480 - y1_output_loss: 0.1246 - y2_output_loss: 0.2213 - y1_output_root_mean_squared_error: 0.3533 - y2_output_root_mean_squared_error: 0.4724 - val_loss: 0.6239 - val_y1_output_loss: 0.1968 - val_y2_output_loss: 0.4201 - val_y1_output_root_mean_squared_error: 0.4416 - val_y2_output_root_mean_squared_error: 0.6549
# Epoch 480/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.3457 - y1_output_loss: 0.1071 - y2_output_loss: 0.2362 - y1_output_root_mean_squared_error: 0.3286 - y2_output_root_mean_squared_error: 0.4876 - val_loss: 0.5521 - val_y1_output_loss: 0.1788 - val_y2_output_loss: 0.3615 - val_y1_output_root_mean_squared_error: 0.4246 - val_y2_output_root_mean_squared_error: 0.6098
# Epoch 481/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3760 - y1_output_loss: 0.1043 - y2_output_loss: 0.2703 - y1_output_root_mean_squared_error: 0.3240 - y2_output_root_mean_squared_error: 0.5206 - val_loss: 0.6145 - val_y1_output_loss: 0.1954 - val_y2_output_loss: 0.4126 - val_y1_output_root_mean_squared_error: 0.4375 - val_y2_output_root_mean_squared_error: 0.6504
# Epoch 482/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.3989 - y1_output_loss: 0.1163 - y2_output_loss: 0.2805 - y1_output_root_mean_squared_error: 0.3415 - y2_output_root_mean_squared_error: 0.5313 - val_loss: 0.6197 - val_y1_output_loss: 0.1925 - val_y2_output_loss: 0.4203 - val_y1_output_root_mean_squared_error: 0.4376 - val_y2_output_root_mean_squared_error: 0.6544
# Epoch 483/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.3256 - y1_output_loss: 0.1076 - y2_output_loss: 0.2161 - y1_output_root_mean_squared_error: 0.3285 - y2_output_root_mean_squared_error: 0.4665 - val_loss: 0.6968 - val_y1_output_loss: 0.1926 - val_y2_output_loss: 0.5115 - val_y1_output_root_mean_squared_error: 0.4323 - val_y2_output_root_mean_squared_error: 0.7141
# Epoch 484/500
# 614/614 [==============================] - 0s 183us/sample - loss: 0.3048 - y1_output_loss: 0.1042 - y2_output_loss: 0.1994 - y1_output_root_mean_squared_error: 0.3236 - y2_output_root_mean_squared_error: 0.4473 - val_loss: 0.5531 - val_y1_output_loss: 0.1966 - val_y2_output_loss: 0.3588 - val_y1_output_root_mean_squared_error: 0.4378 - val_y2_output_root_mean_squared_error: 0.6012
# Epoch 485/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.3373 - y1_output_loss: 0.1123 - y2_output_loss: 0.2242 - y1_output_root_mean_squared_error: 0.3336 - y2_output_root_mean_squared_error: 0.4754 - val_loss: 0.6020 - val_y1_output_loss: 0.2126 - val_y2_output_loss: 0.3821 - val_y1_output_root_mean_squared_error: 0.4606 - val_y2_output_root_mean_squared_error: 0.6244
# Epoch 486/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.4602 - y1_output_loss: 0.1568 - y2_output_loss: 0.3015 - y1_output_root_mean_squared_error: 0.3976 - y2_output_root_mean_squared_error: 0.5496 - val_loss: 0.8280 - val_y1_output_loss: 0.2387 - val_y2_output_loss: 0.5718 - val_y1_output_root_mean_squared_error: 0.4908 - val_y2_output_root_mean_squared_error: 0.7662
# Epoch 487/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.4636 - y1_output_loss: 0.1320 - y2_output_loss: 0.3303 - y1_output_root_mean_squared_error: 0.3618 - y2_output_root_mean_squared_error: 0.5768 - val_loss: 0.8207 - val_y1_output_loss: 0.2975 - val_y2_output_loss: 0.5408 - val_y1_output_root_mean_squared_error: 0.5312 - val_y2_output_root_mean_squared_error: 0.7338
# Epoch 488/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.2657 - y1_output_loss: 0.0948 - y2_output_loss: 0.1724 - y1_output_root_mean_squared_error: 0.3087 - y2_output_root_mean_squared_error: 0.4128 - val_loss: 0.6812 - val_y1_output_loss: 0.2029 - val_y2_output_loss: 0.4659 - val_y1_output_root_mean_squared_error: 0.4528 - val_y2_output_root_mean_squared_error: 0.6900
# Epoch 489/500
# 614/614 [==============================] - 0s 171us/sample - loss: 0.3588 - y1_output_loss: 0.1226 - y2_output_loss: 0.2344 - y1_output_root_mean_squared_error: 0.3515 - y2_output_root_mean_squared_error: 0.4850 - val_loss: 0.8056 - val_y1_output_loss: 0.2191 - val_y2_output_loss: 0.5882 - val_y1_output_root_mean_squared_error: 0.4648 - val_y2_output_root_mean_squared_error: 0.7679
# Epoch 490/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.3551 - y1_output_loss: 0.1191 - y2_output_loss: 0.2332 - y1_output_root_mean_squared_error: 0.3458 - y2_output_root_mean_squared_error: 0.4853 - val_loss: 0.5998 - val_y1_output_loss: 0.2054 - val_y2_output_loss: 0.3836 - val_y1_output_root_mean_squared_error: 0.4552 - val_y2_output_root_mean_squared_error: 0.6266
# Epoch 491/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.3082 - y1_output_loss: 0.1060 - y2_output_loss: 0.2006 - y1_output_root_mean_squared_error: 0.3266 - y2_output_root_mean_squared_error: 0.4490 - val_loss: 0.6838 - val_y1_output_loss: 0.2042 - val_y2_output_loss: 0.4814 - val_y1_output_root_mean_squared_error: 0.4513 - val_y2_output_root_mean_squared_error: 0.6929
# Epoch 492/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.2864 - y1_output_loss: 0.1077 - y2_output_loss: 0.1790 - y1_output_root_mean_squared_error: 0.3269 - y2_output_root_mean_squared_error: 0.4238 - val_loss: 0.5771 - val_y1_output_loss: 0.2167 - val_y2_output_loss: 0.3507 - val_y1_output_root_mean_squared_error: 0.4684 - val_y2_output_root_mean_squared_error: 0.5981
# Epoch 493/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.3504 - y1_output_loss: 0.1056 - y2_output_loss: 0.2472 - y1_output_root_mean_squared_error: 0.3259 - y2_output_root_mean_squared_error: 0.4942 - val_loss: 0.9431 - val_y1_output_loss: 0.2755 - val_y2_output_loss: 0.6831 - val_y1_output_root_mean_squared_error: 0.5184 - val_y2_output_root_mean_squared_error: 0.8212
# Epoch 494/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.3008 - y1_output_loss: 0.1008 - y2_output_loss: 0.1995 - y1_output_root_mean_squared_error: 0.3183 - y2_output_root_mean_squared_error: 0.4466 - val_loss: 0.6659 - val_y1_output_loss: 0.2197 - val_y2_output_loss: 0.4323 - val_y1_output_root_mean_squared_error: 0.4711 - val_y2_output_root_mean_squared_error: 0.6663
# Epoch 495/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.3151 - y1_output_loss: 0.1157 - y2_output_loss: 0.1970 - y1_output_root_mean_squared_error: 0.3415 - y2_output_root_mean_squared_error: 0.4455 - val_loss: 0.6179 - val_y1_output_loss: 0.2298 - val_y2_output_loss: 0.3786 - val_y1_output_root_mean_squared_error: 0.4805 - val_y2_output_root_mean_squared_error: 0.6221
# Epoch 496/500
# 614/614 [==============================] - 0s 171us/sample - loss: 0.4601 - y1_output_loss: 0.1441 - y2_output_loss: 0.3217 - y1_output_root_mean_squared_error: 0.3794 - y2_output_root_mean_squared_error: 0.5622 - val_loss: 1.5582 - val_y1_output_loss: 0.4789 - val_y2_output_loss: 1.0595 - val_y1_output_root_mean_squared_error: 0.7008 - val_y2_output_root_mean_squared_error: 1.0330
# Epoch 497/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.3306 - y1_output_loss: 0.1253 - y2_output_loss: 0.2034 - y1_output_root_mean_squared_error: 0.3553 - y2_output_root_mean_squared_error: 0.4520 - val_loss: 0.6572 - val_y1_output_loss: 0.1883 - val_y2_output_loss: 0.4555 - val_y1_output_root_mean_squared_error: 0.4351 - val_y2_output_root_mean_squared_error: 0.6840
# Epoch 498/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.3101 - y1_output_loss: 0.1163 - y2_output_loss: 0.1944 - y1_output_root_mean_squared_error: 0.3407 - y2_output_root_mean_squared_error: 0.4405 - val_loss: 0.6269 - val_y1_output_loss: 0.2340 - val_y2_output_loss: 0.3795 - val_y1_output_root_mean_squared_error: 0.4901 - val_y2_output_root_mean_squared_error: 0.6218
# Epoch 499/500
# 614/614 [==============================] - 0s 169us/sample - loss: 0.3155 - y1_output_loss: 0.1018 - y2_output_loss: 0.2178 - y1_output_root_mean_squared_error: 0.3201 - y2_output_root_mean_squared_error: 0.4616 - val_loss: 1.5668 - val_y1_output_loss: 0.3483 - val_y2_output_loss: 1.2480 - val_y1_output_root_mean_squared_error: 0.5909 - val_y2_output_root_mean_squared_error: 1.1035
# Epoch 500/500
# 614/614 [==============================] - 0s 171us/sample - loss: 0.3409 - y1_output_loss: 0.1271 - y2_output_loss: 0.2131 - y1_output_root_mean_squared_error: 0.3579 - y2_output_root_mean_squared_error: 0.4614 - val_loss: 0.8845 - val_y1_output_loss: 0.2295 - val_y2_output_loss: 0.6664 - val_y1_output_root_mean_squared_error: 0.4674 - val_y2_output_root_mean_squared_error: 0.8161

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 40us/sample - loss: 0.8845 - y1_output_loss: 0.2201 - y2_output_loss: 0.6632 - y1_output_root_mean_squared_error: 0.4674 - y2_output_root_mean_squared_error: 0.8161
# Loss = 0.8844878038802704, Y1_loss = 0.2201383411884308, Y1_mse = 0.46744582056999207, Y2_loss = 0.6632487177848816, Y2_mse = 0.8160773515701294

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
